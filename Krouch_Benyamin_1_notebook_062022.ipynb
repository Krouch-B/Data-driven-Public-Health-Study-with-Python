# %% [markdown]
# # Réalisez une étude de santé publique avec R ou Python

# %% [markdown]
# ![fao%20logo.PNG](attachment:fao%20logo.PNG)

# %% [markdown]
# ## Importation de Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Création de mes Dataframe
#
# Pour cela rien de plus simple, j'utilise la méthode .read_csv() et je sauvegarde chaque Dataframe dans une variable.

# %%
aide_alimentaire = pd.read_csv("aide_alimentaire.csv")
dispo_alimentaire = pd.read_csv("dispo_alimentaire.csv")
population = pd.read_csv("population.csv")
sous_nutrition = pd.read_csv("sous_nutrition.csv")

# %% [markdown]
# Parfait mes dataframes sont créés , pour les voir il me suffit d' "appeler" les variables auxquelles je les ai associés.

# %%
aide_alimentaire.head()
# Out:
#   Pays bénéficiaire  Année              Produit  Valeur
# 0       Afghanistan   2013  Autres non-céréales     682
# 1       Afghanistan   2014  Autres non-céréales     335
# 2       Afghanistan   2013         Blé et Farin   39224
# 3       Afghanistan   2014         Blé et Farin   15160
# 4       Afghanistan   2013             Céréales   40504

# %%
dispo_alimentaire.head()
# Out:
#           Zone                Produit   Origine  Aliments pour animaux  \
# 0  Afghanistan       Abats Comestible   animale                    NaN
# 1  Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2  Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3  Afghanistan                 Ananas  vegetale                    NaN
# 4  Afghanistan                Bananes  vegetale                    NaN
#
#    Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                  NaN                                             5.0
# 1                  NaN                                             1.0
# 2                  NaN                                             1.0
# 3                  NaN                                             0.0
# 4                  NaN                                             4.0
#
#    Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                               1.72
# 1                                               1.29
# 2                                               0.06
# 3                                               0.00
# 4                                               2.70
#
#    Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                               0.20
# 1                                               0.01
# 2                                               0.01
# 3                                                NaN
# 4                                               0.02
#
#    Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                               0.77
# 1                                               0.02
# 2                                               0.03
# 3                                                NaN
# 4                                               0.05
#
#    Disponibilité intérieure  Exportations - Quantité  Importations - Quantité  \
# 0                      53.0                      NaN                      NaN
# 1                      41.0                      2.0                     40.0
# 2                       2.0                      NaN                      2.0
# 3                       0.0                      NaN                      0.0
# 4                      82.0                      NaN                     82.0
#
#    Nourriture  Pertes  Production  Semences  Traitement  Variation de stock
# 0        53.0     NaN        53.0       NaN         NaN                 NaN
# 1        39.0     2.0         3.0       NaN         NaN                 NaN
# 2         2.0     NaN         NaN       NaN         NaN                 NaN
# 3         0.0     NaN         NaN       NaN         NaN                 NaN
# 4        82.0     NaN         NaN       NaN         NaN                 NaN

# %%
population.head()
# Out:
#           Zone  Année     Valeur
# 0  Afghanistan   2013  32269.589
# 1  Afghanistan   2014  33370.794
# 2  Afghanistan   2015  34413.603
# 3  Afghanistan   2016  35383.032
# 4  Afghanistan   2017  36296.113

# %%
sous_nutrition.head()
# Out:
#           Zone      Année Valeur
# 0  Afghanistan  2012-2014    8.6
# 1  Afghanistan  2013-2015    8.8
# 2  Afghanistan  2014-2016    8.9
# 3  Afghanistan  2015-2017    9.7
# 4  Afghanistan  2016-2018   10.5

# %% [markdown]
# Tout semble s'être bien passé en ce qui concerne l'importation des ficher csv. Passons à la première question.

# %% [markdown]
# # <u>Première question : Quelle est la proportion de personnes en état de sous-nutrition pour l'année 2017 ?</u>
#
# Pour répondre à cette question, nous devons au préalable nous en poser deux autres:<ul>
#
# <li> Quelles est **le nombre de personne en sous alimentation dans le monde** en 2017 ?</li>
# <li> De combien d'individus se compose **la population mondiale en 2017** ?</li>
#
# ## <u>A ) Quelles est le nombre de personne en sous alimentation dans le monde en 2017 ?</u>
# Pour repondre à cette question nous aurons besoin du tableau **"sous_nutrition"**

# %%
sous_nutrition.head()
# Out:
#           Zone      Année Valeur
# 0  Afghanistan  2012-2014    8.6
# 1  Afghanistan  2013-2015    8.8
# 2  Afghanistan  2014-2016    8.9
# 3  Afghanistan  2015-2017    9.7
# 4  Afghanistan  2016-2018   10.5

# %% [markdown]
# Conformément au indication de Julien ce tableau inclut :
#
# -	Le pays.
# -	Intervalle d’années.
# -	Le nombre de personnes en sous-alimentation en millions d’habitants (ex. : pour l’intervalle 2016-2018, le nombre de personnes correspond à la moyenne sur ces 3 années, on peut le résumer en 2017).
#
#  Nous allons donc nous concentrer sur la période **" 2016-2018"** et créer un **" subset "** comprenant les données de la sous_alimentaition que nous sauvegarderons dans une variable appelée **"ss_nut_2017"**.

# %% [markdown]
# Commençons par changer le nom des colonnes afin que ces dernières soient bien plus explicites avec la méthode '.rename'

# %%
sous_nutrition = sous_nutrition.rename(columns={"Zone": "Pays", "Valeur":"Individus en millions d'hab."})

# %%
sous_nutrition.head()
# Out:
#           Pays      Année Individus en millions d'hab.
# 0  Afghanistan  2012-2014                          8.6
# 1  Afghanistan  2013-2015                          8.8
# 2  Afghanistan  2014-2016                          8.9
# 3  Afghanistan  2015-2017                          9.7
# 4  Afghanistan  2016-2018                         10.5

# %% [markdown]
# Nous allons nous concentrer sur la période **" 2016-2018"** et créer un " subset " comprenant les données de la sous_alimentaition que nous sauvegarderons dans une variable appelée **"ss_nut_2017"** .

# %%
ss_nut_2017 = sous_nutrition.loc[sous_nutrition["Année"]== "2016-2018"]
ss_nut_2017.head()
# Out:
#               Pays      Année Individus en millions d'hab.
# 4      Afghanistan  2016-2018                         10.5
# 10  Afrique du Sud  2016-2018                          3.1
# 16         Albanie  2016-2018                          0.1
# 22         Algérie  2016-2018                          1.3
# 28       Allemagne  2016-2018                          NaN

# %% [markdown]
# Nous voyons que nous avons obtenu pour chaque pays les valeurs en millions d'habitants pour la periode **2016-2018**.
#
# Dans un soucis de lisibilité, il serait peut-être plus judicieux de **changer** la formulation **"2016-2018" pour "2017"**

# %%
ss_nut_2017 = ss_nut_2017.replace("2016-2018", 2017)
ss_nut_2017.head()
# Out:
#               Pays  Année Individus en millions d'hab.
# 4      Afghanistan   2017                         10.5
# 10  Afrique du Sud   2017                          3.1
# 16         Albanie   2017                          0.1
# 22         Algérie   2017                          1.3
# 28       Allemagne   2017                          NaN

# %% [markdown]
# Le prochain problème a traiter est celui des valeur nulles:
#
# Commencons par identifier les pays pour lequels nous n'avons aucunes information concernant les individus en sous alimentation en millions d'habitants

# %%
ss_nut_2017.isnull().sum()
# Out:
# Pays                             0
# Année                            0
# Individus en millions d'hab.    99
# dtype: int64

# %% [markdown]
# Nous avons **99 valeurs manquantes** dans la colonne Individus en millions d'hab.

# %%
ss_nut_2017.loc[ss_nut_2017["Individus en millions d'hab."].isnull(),: ].head()
# Out:
#                   Pays  Année Individus en millions d'hab.
# 28           Allemagne   2017                          NaN
# 34             Andorre   2017                          NaN
# 46  Antigua-et-Barbuda   2017                          NaN
# 70           Australie   2017                          NaN
# 76            Autriche   2017                          NaN

# %% [markdown]
# Dès les premières lignes on peut se rendre compte que les pays pour lesquels nous n'avons pas de valeur **semblent êtres des pays riches** avec par exemple l'Allemagne , Andorre, l'australie, l'autriche etc ... La tentation est grande ici, de remplacer ces valeurs nuls par 0 .
#
# Mais c'est sans compter des pays comme **l'Erythrée , la Guinée , le Yemen, le Niger , l'Ouganda et bien d'autre pays pauvre présent dans cette liste**.
#
# Nous ne tiendrons pas commpte des valeurs nulles dans notre calcul nous utiliserons la methode **'.skipna'**, ce qui aura le **même impact que remplacer ces valeurs par 0 tout en ayant l'avantage d'être plus honnête**.

# %% [markdown]
# Occupons nous **des types de données**. Dans le language Python presque tout est un objet et ces objets ont des types : on peut avoir des chaines de caractères ou string, des décimaux ou float, des nombre entiers ou int. On vérifie que chaque colonne est bien associée au bon type. **C' est primordiale pour la compréhension des données**

# %%
ss_nut_2017.dtypes
# Out:
# Pays                            object
# Année                            int64
# Individus en millions d'hab.    object
# dtype: object

# %% [markdown]
# Ici on peut voir qu'à la colonne **"Individus en millions d'hab."** est associé un type **"object"**. Changeons cela pour un type **"float"**.

# %%
ss_nut_2017.astype({"Individus en millions d'hab.": "float"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-206-84ff7df309f1> in <module>
# ----> 1 ss_nut_2017.astype({"Individus en millions d'hab.": "float"})
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5860                 if col_name in dtype:
#    5861                     results.append(
# -> 5862                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5863                     )
#    5864                 else:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1095     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#    1096         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1097         return arr.astype(dtype, copy=True)
#    1098
#    1099     return arr.view(dtype)
#
# ValueError: could not convert string to float: '<0.1'

# %% [markdown]
# Ah mince ! La ligne de code à provoquer une erreur : **"could not convert string to float: '<0.1"**. On peut facilement comprendre, maintenant, pourquoi le type de la colonne **"Individus en millions d'hab."** était **object**. Certaines lignes ont pour valeur **"<0.1"**. Affichons les !

# %%
ss_nut_2017.loc[ss_nut_2017["Individus en millions d'hab."] == '<0.1']
# Out:
#                                  Pays  Année Individus en millions d'hab.
# 64                            Arménie   2017                         <0.1
# 106                           Barbade   2017                         <0.1
# 124                            Belize   2017                         <0.1
# 196                        Cabo Verde   2017                         <0.1
# 232              Chine - RAS de Macao   2017                         <0.1
# 250                            Chypre   2017                         <0.1
# 310                         Dominique   2017                         <0.1
# 382                             Fidji   2017                         <0.1
# 466                            Guyana   2017                         <0.1
# 502                      Îles Salomon   2017                         <0.1
# 592                          Kiribati   2017                         <0.1
# 646                 Macédoine du Nord   2017                         <0.1
# 694                           Maurice   2017                         <0.1
# 790                Nouvelle-Calédonie   2017                         <0.1
# 880               Polynésie française   2017                         <0.1
# 988   Saint-Vincent-et-les Grenadines   2017                         <0.1
# 1006             Sao Tomé-et-Principe   2017                         <0.1
# 1090                         Suriname   2017                         <0.1
# 1144                Trinité-et-Tobago   2017                         <0.1
# 1186                          Vanuatu   2017                         <0.1

# %% [markdown]
# Remplaçons les !

# %%
ss_nut_2017 = ss_nut_2017.replace("<0.1",0)

# %% [markdown]
# On procède maintenant au changement de type:

# %%
ss_nut_2017["Individus en millions d'hab."] = ss_nut_2017["Individus en millions d'hab."].astype("float")

# %%
tot_pop_sn_2017 = ss_nut_2017["Individus en millions d'hab."].sum(skipna=True)*1000000
print('Population en état de sous-alimentation: ' + str(tot_pop_sn_2017))
# Out:
# Population en état de sous-alimentation: 535700000.00000006

# %% [markdown]
# En 2017, cinq cent trente sept millions sept cent mille (537.700.000) personnes étaient en état de sous-nutrition.

# %% [markdown]
# ## <u> B ) De combien d'individus se compose la population mondiale en 2017 ?<u/>
#
# Pour cette question nous aurons besoin du dataframe "**population**".

# %%
population.head()
# Out:
#           Zone  Année     Valeur
# 0  Afghanistan   2013  32269.589
# 1  Afghanistan   2014  33370.794
# 2  Afghanistan   2015  34413.603
# 3  Afghanistan   2016  35383.032
# 4  Afghanistan   2017  36296.113

# %% [markdown]
# On procède au changement du nom des colonnes grace à la méthode **.rename()**.

# %%
population = population.rename(columns={"Zone": "Pays", "Valeur":"Individus en milliers d'hab."})
population.head()
# Out:
#           Pays  Année  Individus en milliers d'hab.
# 0  Afghanistan   2013                     32269.589
# 1  Afghanistan   2014                     33370.794
# 2  Afghanistan   2015                     34413.603
# 3  Afghanistan   2016                     35383.032
# 4  Afghanistan   2017                     36296.113

# %% [markdown]
# Comme pour la population en état de sous-nutrition ce qui nous interesse ici est de connaitre la population mondiale en 2017. On va créer un dataframe **pop_2017 qui ne gardera que les chiffres dont nous avons besoin.**

# %%
pop_2017 = population.loc[population['Année'] == 2017]
pop_2017.head()
# Out:
#               Pays  Année  Individus en milliers d'hab.
# 4      Afghanistan   2017                     36296.113
# 10  Afrique du Sud   2017                     57009.756
# 16         Albanie   2017                      2884.169
# 22         Algérie   2017                     41389.189
# 28       Allemagne   2017                     82658.409

# %% [markdown]
# Parfait, tout se passe comme prévu ! Vérifions que nous n'avons pas de **valeurs nulles** avec la combinaison des méthodes **.isnull() et .sum()**

# %%
pop_2017.isnull().sum()
# Out:
# Pays                            0
# Année                           0
# Individus en milliers d'hab.    0
# dtype: int64

# %% [markdown]
# Aucune valeur nulle ! Vérifions que nous n'avons pas de **doublons** dans ce dataframe grace à la compbinaison de méthodes **.duplicated() et .sum()**

# %%
pop_2017.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Parfait ! Aucun doublons, il aurait été malheureux de compter la population d'un même pays, plus d'une fois.

# %%
pop_mond_2017=round(pop_2017["Individus en milliers d'hab."].sum()* 1000,2)
pop_mond_2017
# Out:
# 7548134111.0

# %%
print('Population mondiale en 2017: ' + str(pop_mond_2017))
# Out:
# Population mondiale en 2017: 7548134111.0

# %% [markdown]
# # <u> Conclusion</u>

# %% [markdown]
# Nous avons maintenant répondu aux deux questions préliminaires, nécéssaires afin de savoir quelle est la proportion de la popuLation mondiale en état de sous-nutrition en 2017.
# Le calcul est simple : il s'agit du rapport **population en sous-nutrition en 2017 divisé par la population mondiale** .

# %%
Pourcentage_ss_nut_2017 = round((tot_pop_sn_2017 / pop_mond_2017)*100,2)
print("Proportion de la population mondiale en état de sous nutrition:", Pourcentage_ss_nut_2017, "%")
# Out:
# Proportion de la population mondiale en état de sous nutrition: 7.1 %

# %% [markdown]
# # <u> Deuxième question : Quel est le  nombre théorique de personnes qui pourraient être nourries en 2017 ?</u>

# %% [markdown]
# Pour cette question nous aurons besoin des df **"dispo_alimentaire"** et **pop_2017**.

# %%
dispo_alimentaire.head()
# Out:
#           Zone                Produit   Origine  Aliments pour animaux  \
# 0  Afghanistan       Abats Comestible   animale                    NaN
# 1  Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2  Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3  Afghanistan                 Ananas  vegetale                    NaN
# 4  Afghanistan                Bananes  vegetale                    NaN
#
#    Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                  NaN                                             5.0
# 1                  NaN                                             1.0
# 2                  NaN                                             1.0
# 3                  NaN                                             0.0
# 4                  NaN                                             4.0
#
#    Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                               1.72
# 1                                               1.29
# 2                                               0.06
# 3                                               0.00
# 4                                               2.70
#
#    Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                               0.20
# 1                                               0.01
# 2                                               0.01
# 3                                                NaN
# 4                                               0.02
#
#    Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                               0.77
# 1                                               0.02
# 2                                               0.03
# 3                                                NaN
# 4                                               0.05
#
#    Disponibilité intérieure  Exportations - Quantité  Importations - Quantité  \
# 0                      53.0                      NaN                      NaN
# 1                      41.0                      2.0                     40.0
# 2                       2.0                      NaN                      2.0
# 3                       0.0                      NaN                      0.0
# 4                      82.0                      NaN                     82.0
#
#    Nourriture  Pertes  Production  Semences  Traitement  Variation de stock
# 0        53.0     NaN        53.0       NaN         NaN                 NaN
# 1        39.0     2.0         3.0       NaN         NaN                 NaN
# 2         2.0     NaN         NaN       NaN         NaN                 NaN
# 3         0.0     NaN         NaN       NaN         NaN                 NaN
# 4        82.0     NaN         NaN       NaN         NaN                 NaN

# %% [markdown]
# Comme pour le df **sous_nutrition**, procédons au renommage des colonnes.

# %%
dispo_alimentaire = dispo_alimentaire.rename(columns={"Zone" : "Pays"})

# %% [markdown]
# Passons au cribles **les types de données** de ce df.

# %%
dispo_alimentaire.dtypes
# Out:
# Pays                                                              object
# Produit                                                           object
# Origine                                                           object
# Aliments pour animaux                                            float64
# Autres Utilisations                                              float64
# Disponibilité alimentaire (Kcal/personne/jour)                   float64
# Disponibilité alimentaire en quantité (kg/personne/an)           float64
# Disponibilité de matière grasse en quantité (g/personne/jour)    float64
# Disponibilité de protéines en quantité (g/personne/jour)         float64
# Disponibilité intérieure                                         float64
# Exportations - Quantité                                          float64
# Importations - Quantité                                          float64
# Nourriture                                                       float64
# Pertes                                                           float64
# Production                                                       float64
# Semences                                                         float64
# Traitement                                                       float64
# Variation de stock                                               float64
# dtype: object

# %% [markdown]
# Tout est en ordre !

# %% [markdown]
# Etant donnée que nous devons établir une proportion par rapport à la population mondiale, nous aurons besoin de procéder à un **.merge()** des deux df.

# %% [markdown]
# Mais avant et dans un soucis de lisibilité, il nous faut un tableau de disponibilité alimentaire par pays. Pour ce faire, on utilisera la combinaison des méthodes **.grouby() et .sum().**

# %%
dispo_alim_par_pays = dispo_alimentaire.groupby("Pays").sum()
dispo_alim_par_pays
# Out:
#                        Aliments pour animaux  Autres Utilisations  \
# Pays
# Afghanistan                            768.0                415.0
# Afrique du Sud                        5309.0                876.0
# Albanie                                660.0                174.0
# Algérie                               4352.0               1707.0
# Allemagne                            30209.0               7711.0
# ...                                      ...                  ...
# Émirats arabes unis                   1174.0               2689.0
# Équateur                              1200.0               1909.0
# États-Unis d'Amérique               148432.0             154699.0
# Éthiopie                               685.0               3641.0
# Îles Salomon                             0.0                237.0
#
#                        Disponibilité alimentaire (Kcal/personne/jour)  \
# Pays
# Afghanistan                                                    2087.0
# Afrique du Sud                                                 3020.0
# Albanie                                                        3188.0
# Algérie                                                        3293.0
# Allemagne                                                      3503.0
# ...                                                               ...
# Émirats arabes unis                                            3275.0
# Équateur                                                       2346.0
# États-Unis d'Amérique                                          3682.0
# Éthiopie                                                       2129.0
# Îles Salomon                                                   2383.0
#
#                        Disponibilité alimentaire en quantité (kg/personne/an)  \
# Pays
# Afghanistan                                                       351.41
# Afrique du Sud                                                    564.80
# Albanie                                                          1095.54
# Algérie                                                           809.13
# Allemagne                                                         957.52
# ...                                                                  ...
# Émirats arabes unis                                               700.24
# Équateur                                                          544.91
# États-Unis d'Amérique                                            1002.39
# Éthiopie                                                          354.55
# Îles Salomon                                                      648.91
#
#                        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Pays
# Afghanistan                                                        33.50
# Afrique du Sud                                                     83.58
# Albanie                                                           106.48
# Algérie                                                            76.48
# Allemagne                                                         141.62
# ...                                                                  ...
# Émirats arabes unis                                                87.16
# Équateur                                                           94.64
# États-Unis d'Amérique                                             161.37
# Éthiopie                                                           25.89
# Îles Salomon                                                       46.99
#
#                        Disponibilité de protéines en quantité (g/personne/jour)  \
# Pays
# Afghanistan                                                        58.26
# Afrique du Sud                                                     85.33
# Albanie                                                           111.37
# Algérie                                                            91.92
# Allemagne                                                         101.39
# ...                                                                  ...
# Émirats arabes unis                                               104.51
# Équateur                                                           61.30
# États-Unis d'Amérique                                             109.42
# Éthiopie                                                           60.39
# Îles Salomon                                                       56.31
#
#                        Disponibilité intérieure  Exportations - Quantité  \
# Pays
# Afghanistan                             13515.0                    278.0
# Afrique du Sud                          61256.0                  11674.0
# Albanie                                  4758.0                     94.0
# Algérie                                 42630.0                    655.0
# Allemagne                              162275.0                  57431.0
# ...                                         ...                      ...
# Émirats arabes unis                     11850.0                   4343.0
# Équateur                                18614.0                   8002.0
# États-Unis d'Amérique                  777992.0                 163524.0
# Éthiopie                                44014.0                    941.0
# Îles Salomon                              695.0                    118.0
#
#                        Importations - Quantité  Nourriture  Pertes  \
# Pays
# Afghanistan                             2988.0     10735.0  1135.0
# Afrique du Sud                          7517.0     29812.0  2193.0
# Albanie                                  933.0      3476.0   276.0
# Algérie                                17403.0     31729.0  3753.0
# Allemagne                              65353.0     79238.0  3781.0
# ...                                        ...         ...     ...
# Émirats arabes unis                    15327.0      6548.0   705.0
# Équateur                                1725.0      8574.0   707.0
# États-Unis d'Amérique                  81887.0    320889.0  7162.0
# Éthiopie                                1711.0     33361.0  2256.0
# Îles Salomon                              81.0       362.0     6.0
#
#                        Production  Semences  Traitement  Variation de stock
# Pays
# Afghanistan               11171.0     395.0        63.0              -368.0
# Afrique du Sud            63263.0     253.0     22819.0              2153.0
# Albanie                    3964.0      55.0       113.0               -45.0
# Algérie                   26359.0     449.0       637.0              -479.0
# Allemagne                154547.0    1551.0     39842.0              -192.0
# ...                           ...       ...         ...                 ...
# Émirats arabes unis        1192.0       3.0       804.0              -327.0
# Équateur                  24337.0     138.0      6200.0               557.0
# États-Unis d'Amérique    894668.0   10403.0    141010.0            -35032.0
# Éthiopie                  46102.0     640.0      3443.0             -2857.0
# Îles Salomon                739.0       0.0        90.0               -10.0
#
# [174 rows x 15 columns]

# %% [markdown]
# Ok ! Pour répondre à cette question, nous n'avons pas **besoin de la totalité des colonnes du df dispo_alimentaire**. Les seul colonnes dont nous avons besoin sont celles du **Pays et de la Disponibilité alimentaire en Kcal par personne et par jour.**

# %%
dispo_alim_groupby = dispo_alimentaire.groupby("Pays")["Pays","Disponibilité alimentaire (Kcal/personne/jour)"].sum()
dispo_alim_groupby.head()
# Out:
# <ipython-input-223-8ad1bfe612d1>:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                 Disponibilité alimentaire (Kcal/personne/jour)
# Pays
# Afghanistan                                             2087.0
# Afrique du Sud                                          3020.0
# Albanie                                                 3188.0
# Algérie                                                 3293.0
# Allemagne                                               3503.0

# %% [markdown]
# Bien, nous disposons maintenant d'un tableau lisible. Il expose clairement **la disponibilité alimentaire pour chaque pays**. Ce qu'il nous reste à faire est **d'associer ce tableau nouvellement créé à celui contenant le nombre d'habitant par pays**. Il faut toutefois noter que les deux df ont un nombre de lignes différents. Le df dispo_alimentaire est composé **de 174 lignes, tandis que le df pop_2017 est composé de 236 lignes**. Ce qui veut dire qu'il y aura forcément des lignes qui ne matcheront pas. en d'autres mots: **des pays pour lesquels nous disposons d'informations en ce qui concerne leurs population mais pas la disponibilité alimentaire.**
#
# Ce qui serait judicieux de faire est de procéder à une **jointure externe afin de pouvoir reconnaitre les Pays pour lesquels nous ne disposons pas d'informations et de sauvegarder ces données dans une variable.**

# %%
dispo_alim_par_pays_outer=pd.merge(dispo_alim_groupby, pop_2017, on='Pays', how='outer', indicator= True)
pays_sans_info = dispo_alim_par_pays_outer.loc[(dispo_alim_par_pays_outer["_merge"]=="right_only")|(dispo_alim_par_pays_outer["_merge"]=="left_only")]
pays_sans_info
# Out:
#                             Pays  \
# 126                  Royaume-Uni
# 152                Tchéquie (la)
# 174                      Andorre
# 175                     Anguilla
# 176  Antilles néerlandaises (ex)
# ..                           ...
# 233                Soudan du Sud
# 234                     Tchéquie
# 235                     Tokélaou
# 236                        Tonga
# 237                       Tuvalu
#
#      Disponibilité alimentaire (Kcal/personne/jour)   Année  \
# 126                                          3425.0     NaN
# 152                                          3255.0     NaN
# 174                                             NaN  2017.0
# 175                                             NaN  2017.0
# 176                                             NaN  2017.0
# ..                                              ...     ...
# 233                                             NaN  2017.0
# 234                                             NaN  2017.0
# 235                                             NaN  2017.0
# 236                                             NaN  2017.0
# 237                                             NaN  2017.0
#
#      Individus en milliers d'hab.      _merge
# 126                           NaN   left_only
# 152                           NaN   left_only
# 174                        77.001  right_only
# 175                        14.584  right_only
# 176                       275.186  right_only
# ..                            ...         ...
# 233                     10910.763  right_only
# 234                     10641.034  right_only
# 235                         1.300  right_only
# 236                       101.998  right_only
# 237                        11.370  right_only
#
# [66 rows x 5 columns]

# %% [markdown]
# Nous allons ensuite associer ces deux tableaux avec un **.merge() inner afin  que n'apparaise uniquement les rangées qui se correspondent**

# %%
dispo_alim_par_pays_inner=pd.merge(dispo_alim_groupby, pop_2017, on='Pays', how='inner')
dispo_alim_par_pays_inner
# Out:
#                       Pays  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0              Afghanistan                                          2087.0
# 1           Afrique du Sud                                          3020.0
# 2                  Albanie                                          3188.0
# 3                  Algérie                                          3293.0
# 4                Allemagne                                          3503.0
# ..                     ...                                             ...
# 167    Émirats arabes unis                                          3275.0
# 168               Équateur                                          2346.0
# 169  États-Unis d'Amérique                                          3682.0
# 170               Éthiopie                                          2129.0
# 171           Îles Salomon                                          2383.0
#
#      Année  Individus en milliers d'hab.
# 0     2017                     36296.113
# 1     2017                     57009.756
# 2     2017                      2884.169
# 3     2017                     41389.189
# 4     2017                     82658.409
# ..     ...                           ...
# 167   2017                      9487.203
# 168   2017                     16785.361
# 169   2017                    325084.756
# 170   2017                    106399.924
# 171   2017                       636.039
#
# [172 rows x 4 columns]

# %% [markdown]
# Pour repondre à cette question nous aurons besoin de procéder en **trois étapes** : d'abord  connaitre **la disponiblité alimentaire en Kcal/jour de chaque pays relativement à son nombre d'habitant.**
# Ensuite, **additionner toutes ces données** pour obtenir la disponibilité mondiale par jour.
# Puis enfin **multiplier le nombre obtenu par 365** afin d'obtenir **la disponibilité alimentaire mondiale par année**.
# Commençons!

# %% [markdown]
# Pour connaitre la **disponiblité alimentaire en Kcal/jour de chaque pays relativement à son nombre d'habitant**, il suffit de créer une nouvelle colonne qui sera **le résultat de la multiplication de la Disponibilité alimentaire (Kcal/personne/jour) et du nombre d'habitants.**

# %%
dispo_alim_par_pays_inner["kcal/jour"]= dispo_alim_par_pays_inner["Disponibilité alimentaire (Kcal/personne/jour)"]* (dispo_alim_par_pays_inner["Individus en milliers d'hab."]*1000)
dispo_alim_par_pays_inner.head()
# Out:
#              Pays  Disponibilité alimentaire (Kcal/personne/jour)  Année  \
# 0     Afghanistan                                          2087.0   2017
# 1  Afrique du Sud                                          3020.0   2017
# 2         Albanie                                          3188.0   2017
# 3         Algérie                                          3293.0   2017
# 4       Allemagne                                          3503.0   2017
#
#    Individus en milliers d'hab.     kcal/jour
# 0                     36296.113  7.574999e+10
# 1                     57009.756  1.721695e+11
# 2                      2884.169  9.194731e+09
# 3                     41389.189  1.362946e+11
# 4                     82658.409  2.895524e+11

# %% [markdown]
# Chaque ligne de la colonne **Kcal/jour renvoit à la disponibilité alimentaire de chaque pays /jour relativement à son nombre d'habitant**. Deuxième étape : **additionner toutes ces données afin d'avoir la disponibilité alimentaire mondiale par jour**

# %%
dispo_alim_mondiale_par_jour=dispo_alim_par_pays_inner["kcal/jour"].sum(skipna=True)
print( " La disponibilité alimentaire mondiale par jour est de :",  dispo_alim_mondiale_par_jour, "Kcal/jour")
# Out:
#  La disponibilité alimentaire mondiale par jour est de : 20918984627331.0 Kcal/jour

# %% [markdown]
# Multiplions ce nombre **par 365 afin de connaitre la disponibilité alimentaire mondiale sur l'année 2017**.

# %%
 dispo_alim_mondiale_2017 =dispo_alim_mondiale_par_jour*365

# %%
print ( "La disponibilité alimentaire 2017 est de :" , dispo_alim_mondiale_2017, "Kcal.")
# Out:
# La disponibilité alimentaire 2017 est de : 7635429388975815.0 Kcal.

# %% [markdown]
# Afin de savoir quel est **le nombre théorique de personnes qui pourraient être nourries en 2017**. Il faut opposer la disponibilité alimentaire mondiale de 2017 en Kcal **au besoin calorique en Kcal de la population mondiale de 2017**.
# D'après la **F.A.O les besoins journaliers en Kcal d'un être humain sont d'environs 2200 Kcal**.

# %%
besoin_calorique_journaliers_en_kcal= 2200

# %% [markdown]
# Le besoin calorique mondiale en 2017 est donc **de 2200 fois la population mondiale de 2017 fois trois cent soixante cinq jours**

# %%
besoin_calorique_mondiale_2017= besoin_calorique_journaliers_en_kcal*pop_mond_2017*365

# %%
besoin_calorique_mondiale_2017
# Out:
# 6061151691133000.0

# %%
Nb_theorique=round((dispo_alim_mondiale_2017/besoin_calorique_mondiale_2017)*pop_mond_2017,2)
Nb_theorique
# Out:
# 9508629376.06

# %% [markdown]
# # <u>Troisième question : Le nombre théorique de personnes qui pourraient être nourries en 2017 grace au produit vegetaux ?</u>

# %% [markdown]
# Nous suivrons ici le même raisonnement que pour la question précédente

# %%
dispo_alimentaire_vegetale = dispo_alimentaire.loc[dispo_alimentaire["Origine"]=="vegetale"]
dispo_alimentaire_vegetale.head()
# Out:
#           Pays                Produit   Origine  Aliments pour animaux  \
# 1  Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2  Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3  Afghanistan                 Ananas  vegetale                    NaN
# 4  Afghanistan                Bananes  vegetale                    NaN
# 6  Afghanistan                  Bière  vegetale                    NaN
#
#    Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 1                  NaN                                             1.0
# 2                  NaN                                             1.0
# 3                  NaN                                             0.0
# 4                  NaN                                             4.0
# 6                  NaN                                             0.0
#
#    Disponibilité alimentaire en quantité (kg/personne/an)  \
# 1                                               1.29
# 2                                               0.06
# 3                                               0.00
# 4                                               2.70
# 6                                               0.09
#
#    Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 1                                               0.01
# 2                                               0.01
# 3                                                NaN
# 4                                               0.02
# 6                                                NaN
#
#    Disponibilité de protéines en quantité (g/personne/jour)  \
# 1                                               0.02
# 2                                               0.03
# 3                                                NaN
# 4                                               0.05
# 6                                               0.00
#
#    Disponibilité intérieure  Exportations - Quantité  Importations - Quantité  \
# 1                      41.0                      2.0                     40.0
# 2                       2.0                      NaN                      2.0
# 3                       0.0                      NaN                      0.0
# 4                      82.0                      NaN                     82.0
# 6                       3.0                      NaN                      3.0
#
#    Nourriture  Pertes  Production  Semences  Traitement  Variation de stock
# 1        39.0     2.0         3.0       NaN         NaN                 NaN
# 2         2.0     NaN         NaN       NaN         NaN                 NaN
# 3         0.0     NaN         NaN       NaN         NaN                 NaN
# 4        82.0     NaN         NaN       NaN         NaN                 NaN
# 6         3.0     NaN         NaN       NaN         NaN                 NaN

# %%
dispo_alimentaire_vegetale_par_pays= dispo_alimentaire_vegetale.groupby("Pays").sum()
dispo_alimentaire_vegetale_par_pays
# Out:
#                        Aliments pour animaux  Autres Utilisations  \
# Pays
# Afghanistan                            645.0                415.0
# Afrique du Sud                        5122.0                761.0
# Albanie                                559.0                172.0
# Algérie                               4352.0               1706.0
# Allemagne                            28122.0               6842.0
# ...                                      ...                  ...
# Émirats arabes unis                   1174.0               2619.0
# Équateur                              1001.0               1905.0
# États-Unis d'Amérique               145289.0             145102.0
# Éthiopie                               667.0               3641.0
# Îles Salomon                             0.0                229.0
#
#                        Disponibilité alimentaire (Kcal/personne/jour)  \
# Pays
# Afghanistan                                                    1871.0
# Afrique du Sud                                                 2533.0
# Albanie                                                        2203.0
# Algérie                                                        2915.0
# Allemagne                                                      2461.0
# ...                                                               ...
# Émirats arabes unis                                            2718.0
# Équateur                                                       1732.0
# États-Unis d'Amérique                                          2698.0
# Éthiopie                                                       2005.0
# Îles Salomon                                                   2187.0
#
#                        Disponibilité alimentaire en quantité (kg/personne/an)  \
# Pays
# Afghanistan                                                       271.49
# Afrique du Sud                                                    425.17
# Albanie                                                           706.49
# Algérie                                                           632.35
# Allemagne                                                         568.82
# ...                                                                  ...
# Émirats arabes unis                                               473.18
# Équateur                                                          327.21
# États-Unis d'Amérique                                             590.68
# Éthiopie                                                          300.99
# Îles Salomon                                                      587.08
#
#                        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Pays
# Afghanistan                                                        18.27
# Afrique du Sud                                                     48.92
# Albanie                                                            38.76
# Algérie                                                            54.12
# Allemagne                                                          63.63
# ...                                                                  ...
# Émirats arabes unis                                                53.00
# Équateur                                                           49.48
# États-Unis d'Amérique                                              93.68
# Éthiopie                                                           17.88
# Îles Salomon                                                       34.27
#
#                        Disponibilité de protéines en quantité (g/personne/jour)  \
# Pays
# Afghanistan                                                        46.05
# Afrique du Sud                                                     48.94
# Albanie                                                            51.96
# Algérie                                                            66.94
# Allemagne                                                          39.90
# ...                                                                  ...
# Émirats arabes unis                                                62.81
# Équateur                                                           24.80
# États-Unis d'Amérique                                              39.65
# Éthiopie                                                           52.70
# Îles Salomon                                                       38.86
#
#                        Disponibilité intérieure  Exportations - Quantité  \
# Pays
# Afghanistan                             10884.0                    278.0
# Afrique du Sud                          53439.0                  10586.0
# Albanie                                  3326.0                     84.0
# Algérie                                 35510.0                    649.0
# Allemagne                              126866.0                  34454.0
# ...                                         ...                      ...
# Émirats arabes unis                      9623.0                   3326.0
# Équateur                                14926.0                   7142.0
# États-Unis d'Amérique                  632023.0                 140442.0
# Éthiopie                                38824.0                    918.0
# Îles Salomon                              651.0                     98.0
#
#                        Importations - Quantité  Nourriture  Pertes  \
# Pays
# Afghanistan                             2638.0      8293.0  1072.0
# Afrique du Sud                          6468.0     22441.0  2110.0
# Albanie                                  846.0      2241.0   182.0
# Algérie                                14672.0     24797.0  3587.0
# Allemagne                              50642.0     47079.0  3717.0
# ...                                        ...         ...     ...
# Émirats arabes unis                    12546.0      4426.0   675.0
# Équateur                                1475.0      5149.0   654.0
# États-Unis d'Amérique                  69522.0    189122.0  6937.0
# Éthiopie                                1694.0     28320.0  2125.0
# Îles Salomon                              69.0       327.0     6.0
#
#                        Production  Semences  Traitement  Variation de stock
# Pays
# Afghanistan                8891.0     393.0        63.0              -368.0
# Afrique du Sud            55649.0     186.0     22819.0              1912.0
# Albanie                    2609.0      55.0       113.0               -45.0
# Algérie                   21964.0     428.0       637.0              -479.0
# Allemagne                110926.0    1475.0     39686.0              -247.0
# ...                           ...       ...         ...                 ...
# Émirats arabes unis         780.0       0.0       804.0              -376.0
# Équateur                  20042.0     125.0      6200.0               555.0
# États-Unis d'Amérique    740194.0    9030.0    140986.0            -37242.0
# Éthiopie                  40907.0     635.0      3443.0             -2857.0
# Îles Salomon                691.0       0.0        90.0               -10.0
#
# [174 rows x 15 columns]

# %%
dispo_alimentaire_vegetale_groupby=dispo_alimentaire_vegetale.groupby("Pays")["Pays","Disponibilité alimentaire (Kcal/personne/jour)"].sum()
# Out:
# <ipython-input-236-4682c6249acf>:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
dispo_alim_vege_par_pays_inner= pd.merge(dispo_alimentaire_vegetale_groupby, pop_2017, on='Pays', how='inner')
dispo_alim_vege_par_pays_inner.head()
# Out:
#              Pays  Disponibilité alimentaire (Kcal/personne/jour)  Année  \
# 0     Afghanistan                                          1871.0   2017
# 1  Afrique du Sud                                          2533.0   2017
# 2         Albanie                                          2203.0   2017
# 3         Algérie                                          2915.0   2017
# 4       Allemagne                                          2461.0   2017
#
#    Individus en milliers d'hab.
# 0                     36296.113
# 1                     57009.756
# 2                      2884.169
# 3                     41389.189
# 4                     82658.409

# %%
dispo_alim_vege_par_pays_inner["kcal/jour"]= dispo_alim_vege_par_pays_inner["Disponibilité alimentaire (Kcal/personne/jour)"]* (dispo_alim_par_pays_inner["Individus en milliers d'hab."]*1000)
dispo_alim_vege_par_pays_inner.head()
# Out:
#              Pays  Disponibilité alimentaire (Kcal/personne/jour)  Année  \
# 0     Afghanistan                                          1871.0   2017
# 1  Afrique du Sud                                          2533.0   2017
# 2         Albanie                                          2203.0   2017
# 3         Algérie                                          2915.0   2017
# 4       Allemagne                                          2461.0   2017
#
#    Individus en milliers d'hab.     kcal/jour
# 0                     36296.113  6.791003e+10
# 1                     57009.756  1.444057e+11
# 2                      2884.169  6.353824e+09
# 3                     41389.189  1.206495e+11
# 4                     82658.409  2.034223e+11

# %%
dispo_alim_vege_mondiale_par_jour= dispo_alim_vege_par_pays_inner["kcal/jour"].sum(skipna=True)
dispo_alim_vege_mondiale_par_jour
# Out:
# 17260764211501.0

# %%
dispo_alim_vege_mondiale_2017= dispo_alim_vege_mondiale_par_jour* 365
dispo_alim_vege_mondiale_2017
# Out:
# 6300178937197865.0

# %%
quotient= dispo_alim_vege_mondiale_2017/besoin_calorique_mondiale_2017
quotient
# Out:
# 1.0394359452205335

# %% [markdown]
# Le fait que ce quotient soit supérieur à 1 démontre que plus de 100 % de la population mondiale pourrait être nourries grace à la disponibilité alimentaire végétale.

# %%
pop_mond_2017*quotient
# Out:
# 7845801914.318636

# %% [markdown]
# # <u>Quatrième question: Comment est utilisée de la disponibilité intérieure, en particulier la part qui est attribuée à l’alimentation animale, celle qui est perdue et celle qui est concrètement utilisée pour l'alimentation humaine ?</u>

# %% [markdown]
# Pour répondre à cette question nous utliserons le df **dispo_alimentaire**.

# %%
dispo_alimentaire
# Out:
#                Pays                Produit   Origine  Aliments pour animaux  \
# 0       Afghanistan       Abats Comestible   animale                    NaN
# 1       Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2       Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3       Afghanistan                 Ananas  vegetale                    NaN
# 4       Afghanistan                Bananes  vegetale                    NaN
# ...             ...                    ...       ...                    ...
# 15600  Îles Salomon       Viande de Suides   animale                    NaN
# 15601  Îles Salomon    Viande de Volailles   animale                    NaN
# 15602  Îles Salomon          Viande, Autre   animale                    NaN
# 15603  Îles Salomon                    Vin  vegetale                    NaN
# 15604  Îles Salomon         Épices, Autres  vegetale                    NaN
#
#        Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                      NaN                                             5.0
# 1                      NaN                                             1.0
# 2                      NaN                                             1.0
# 3                      NaN                                             0.0
# 4                      NaN                                             4.0
# ...                    ...                                             ...
# 15600                  NaN                                            45.0
# 15601                  NaN                                            11.0
# 15602                  NaN                                             0.0
# 15603                  NaN                                             0.0
# 15604                  NaN                                             4.0
#
#        Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                                   1.72
# 1                                                   1.29
# 2                                                   0.06
# 3                                                   0.00
# 4                                                   2.70
# ...                                                  ...
# 15600                                               4.70
# 15601                                               3.34
# 15602                                               0.06
# 15603                                               0.07
# 15604                                               0.48
#
#        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                                   0.20
# 1                                                   0.01
# 2                                                   0.01
# 3                                                    NaN
# 4                                                   0.02
# ...                                                  ...
# 15600                                               4.28
# 15601                                               0.69
# 15602                                                NaN
# 15603                                                NaN
# 15604                                               0.21
#
#        Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                                   0.77
# 1                                                   0.02
# 2                                                   0.03
# 3                                                    NaN
# 4                                                   0.05
# ...                                                  ...
# 15600                                               1.41
# 15601                                               1.14
# 15602                                               0.04
# 15603                                                NaN
# 15604                                               0.15
#
#        Disponibilité intérieure  Exportations - Quantité  \
# 0                          53.0                      NaN
# 1                          41.0                      2.0
# 2                           2.0                      NaN
# 3                           0.0                      NaN
# 4                          82.0                      NaN
# ...                         ...                      ...
# 15600                       3.0                      NaN
# 15601                       2.0                      NaN
# 15602                       0.0                      NaN
# 15603                       0.0                      0.0
# 15604                       0.0                      0.0
#
#        Importations - Quantité  Nourriture  Pertes  Production  Semences  \
# 0                          NaN        53.0     NaN        53.0       NaN
# 1                         40.0        39.0     2.0         3.0       NaN
# 2                          2.0         2.0     NaN         NaN       NaN
# 3                          0.0         0.0     NaN         NaN       NaN
# 4                         82.0        82.0     NaN         NaN       NaN
# ...                        ...         ...     ...         ...       ...
# 15600                      0.0         3.0     NaN         2.0       NaN
# 15601                      2.0         2.0     NaN         0.0       NaN
# 15602                      0.0         0.0     NaN         NaN       NaN
# 15603                      0.0         0.0     NaN         NaN       NaN
# 15604                      0.0         0.0     NaN         0.0       NaN
#
#        Traitement  Variation de stock
# 0             NaN                 NaN
# 1             NaN                 NaN
# 2             NaN                 NaN
# 3             NaN                 NaN
# 4             NaN                 NaN
# ...           ...                 ...
# 15600         NaN                 NaN
# 15601         NaN                 NaN
# 15602         NaN                 NaN
# 15603         NaN                 NaN
# 15604         NaN                 NaN
#
# [15605 rows x 18 columns]

# %% [markdown]
# **Groupement par pays**

# %%
dispo_alimentaire.groupby("Pays").sum()
# Out:
#                        Aliments pour animaux  Autres Utilisations  \
# Pays
# Afghanistan                            768.0                415.0
# Afrique du Sud                        5309.0                876.0
# Albanie                                660.0                174.0
# Algérie                               4352.0               1707.0
# Allemagne                            30209.0               7711.0
# ...                                      ...                  ...
# Émirats arabes unis                   1174.0               2689.0
# Équateur                              1200.0               1909.0
# États-Unis d'Amérique               148432.0             154699.0
# Éthiopie                               685.0               3641.0
# Îles Salomon                             0.0                237.0
#
#                        Disponibilité alimentaire (Kcal/personne/jour)  \
# Pays
# Afghanistan                                                    2087.0
# Afrique du Sud                                                 3020.0
# Albanie                                                        3188.0
# Algérie                                                        3293.0
# Allemagne                                                      3503.0
# ...                                                               ...
# Émirats arabes unis                                            3275.0
# Équateur                                                       2346.0
# États-Unis d'Amérique                                          3682.0
# Éthiopie                                                       2129.0
# Îles Salomon                                                   2383.0
#
#                        Disponibilité alimentaire en quantité (kg/personne/an)  \
# Pays
# Afghanistan                                                       351.41
# Afrique du Sud                                                    564.80
# Albanie                                                          1095.54
# Algérie                                                           809.13
# Allemagne                                                         957.52
# ...                                                                  ...
# Émirats arabes unis                                               700.24
# Équateur                                                          544.91
# États-Unis d'Amérique                                            1002.39
# Éthiopie                                                          354.55
# Îles Salomon                                                      648.91
#
#                        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Pays
# Afghanistan                                                        33.50
# Afrique du Sud                                                     83.58
# Albanie                                                           106.48
# Algérie                                                            76.48
# Allemagne                                                         141.62
# ...                                                                  ...
# Émirats arabes unis                                                87.16
# Équateur                                                           94.64
# États-Unis d'Amérique                                             161.37
# Éthiopie                                                           25.89
# Îles Salomon                                                       46.99
#
#                        Disponibilité de protéines en quantité (g/personne/jour)  \
# Pays
# Afghanistan                                                        58.26
# Afrique du Sud                                                     85.33
# Albanie                                                           111.37
# Algérie                                                            91.92
# Allemagne                                                         101.39
# ...                                                                  ...
# Émirats arabes unis                                               104.51
# Équateur                                                           61.30
# États-Unis d'Amérique                                             109.42
# Éthiopie                                                           60.39
# Îles Salomon                                                       56.31
#
#                        Disponibilité intérieure  Exportations - Quantité  \
# Pays
# Afghanistan                             13515.0                    278.0
# Afrique du Sud                          61256.0                  11674.0
# Albanie                                  4758.0                     94.0
# Algérie                                 42630.0                    655.0
# Allemagne                              162275.0                  57431.0
# ...                                         ...                      ...
# Émirats arabes unis                     11850.0                   4343.0
# Équateur                                18614.0                   8002.0
# États-Unis d'Amérique                  777992.0                 163524.0
# Éthiopie                                44014.0                    941.0
# Îles Salomon                              695.0                    118.0
#
#                        Importations - Quantité  Nourriture  Pertes  \
# Pays
# Afghanistan                             2988.0     10735.0  1135.0
# Afrique du Sud                          7517.0     29812.0  2193.0
# Albanie                                  933.0      3476.0   276.0
# Algérie                                17403.0     31729.0  3753.0
# Allemagne                              65353.0     79238.0  3781.0
# ...                                        ...         ...     ...
# Émirats arabes unis                    15327.0      6548.0   705.0
# Équateur                                1725.0      8574.0   707.0
# États-Unis d'Amérique                  81887.0    320889.0  7162.0
# Éthiopie                                1711.0     33361.0  2256.0
# Îles Salomon                              81.0       362.0     6.0
#
#                        Production  Semences  Traitement  Variation de stock
# Pays
# Afghanistan               11171.0     395.0        63.0              -368.0
# Afrique du Sud            63263.0     253.0     22819.0              2153.0
# Albanie                    3964.0      55.0       113.0               -45.0
# Algérie                   26359.0     449.0       637.0              -479.0
# Allemagne                154547.0    1551.0     39842.0              -192.0
# ...                           ...       ...         ...                 ...
# Émirats arabes unis        1192.0       3.0       804.0              -327.0
# Équateur                  24337.0     138.0      6200.0               557.0
# États-Unis d'Amérique    894668.0   10403.0    141010.0            -35032.0
# Éthiopie                  46102.0     640.0      3443.0             -2857.0
# Îles Salomon                739.0       0.0        90.0               -10.0
#
# [174 rows x 15 columns]

# %%
disponibilité_interieure_mondiale =dispo_alimentaire["Disponibilité intérieure"].sum()
print( "La disponibilité interieure mondiale en milliers de tonnes est égale à :", disponibilité_interieure_mondiale)
# Out:
# La disponibilité interieure mondiale en milliers de tonnes est égale à : 9848994.0

# %%
part_animaux = round((dispo_alimentaire["Aliments pour animaux"].sum()/ disponibilité_interieure_mondiale),2)*100
print ("La proportion attribuée au animaux est de :", part_animaux, "%")
# Out:
# La proportion attribuée au animaux est de : 13.0 %

# %%
part_perdue = round((dispo_alimentaire["Pertes"].sum()/ disponibilité_interieure_mondiale),2)*100
print ("La proportion perdue de :" , part_perdue,"%")
# Out:
# La proportion perdue de :, 5.0 %

# %%
part_alim_humaine = round ((dispo_alimentaire["Nourriture"].sum()/ disponibilité_interieure_mondiale),2)*100
print ("La proportion attribuée à l'alimentation humaine est de :", part_alim_humaine, "%")
# Out:
# La proportion attribuée à l'alimentation humaine est de : 50.0 %

# %% [markdown]
# # Question de Melanie

# %% [markdown]
# #  Première question : Quels sont les pays pour lesquels la proportion de personnes sous-alimentées est la plus forte en 2017.

# %% [markdown]
# Pour répondre à cette question on aura besoin des df ss_nut_2017 et pop_2017 que l'on va associer

# %%
ss_nut_2017.shape, pop_2017.shape
# Out:
# ((203, 3), (236, 3))

# %% [markdown]
# Etant donnée le nombre de lignes des deux df nous aurons au moins 33 élements qui ne matcheront pas.

# %%
merge_ss_nut_pop_2017= pd.merge(ss_nut_2017, pop_2017, on='Pays', how='inner')
merge_ss_nut_pop_2017
# Out:
#                                        Pays  Année_x  \
# 0                               Afghanistan     2017
# 1                            Afrique du Sud     2017
# 2                                   Albanie     2017
# 3                                   Algérie     2017
# 4                                 Allemagne     2017
# ..                                      ...      ...
# 198  Venezuela (République bolivarienne du)     2017
# 199                                Viet Nam     2017
# 200                                   Yémen     2017
# 201                                  Zambie     2017
# 202                                Zimbabwe     2017
#
#      Individus en millions d'hab.  Année_y  Individus en milliers d'hab.
# 0                            10.5     2017                     36296.113
# 1                             3.1     2017                     57009.756
# 2                             0.1     2017                      2884.169
# 3                             1.3     2017                     41389.189
# 4                             NaN     2017                     82658.409
# ..                            ...      ...                           ...
# 198                           8.0     2017                     29402.484
# 199                           6.5     2017                     94600.648
# 200                           NaN     2017                     27834.819
# 201                           NaN     2017                     16853.599
# 202                           NaN     2017                     14236.595
#
# [203 rows x 5 columns]

# %%
pop_2017
# Out:
#                                         Pays  Année  \
# 4                                Afghanistan   2017
# 10                            Afrique du Sud   2017
# 16                                   Albanie   2017
# 22                                   Algérie   2017
# 28                                 Allemagne   2017
# ...                                      ...    ...
# 1390  Venezuela (République bolivarienne du)   2017
# 1396                                Viet Nam   2017
# 1402                                   Yémen   2017
# 1408                                  Zambie   2017
# 1414                                Zimbabwe   2017
#
#       Individus en milliers d'hab.
# 4                        36296.113
# 10                       57009.756
# 16                        2884.169
# 22                       41389.189
# 28                       82658.409
# ...                            ...
# 1390                     29402.484
# 1396                     94600.648
# 1402                     27834.819
# 1408                     16853.599
# 1414                     14236.595
#
# [236 rows x 3 columns]

# %%
merge_ss_nut_pop_2017["prop. de la pop en ss-alim."]= round((merge_ss_nut_pop_2017["Individus en millions d\'hab."]*1000000) / (merge_ss_nut_pop_2017["Individus en milliers d\'hab."]*1000),2)*100
merge_ss_nut_pop_2017
# Out:
#                                        Pays  Année_x  \
# 0                               Afghanistan     2017
# 1                            Afrique du Sud     2017
# 2                                   Albanie     2017
# 3                                   Algérie     2017
# 4                                 Allemagne     2017
# ..                                      ...      ...
# 198  Venezuela (République bolivarienne du)     2017
# 199                                Viet Nam     2017
# 200                                   Yémen     2017
# 201                                  Zambie     2017
# 202                                Zimbabwe     2017
#
#      Individus en millions d'hab.  Année_y  Individus en milliers d'hab.  \
# 0                            10.5     2017                     36296.113
# 1                             3.1     2017                     57009.756
# 2                             0.1     2017                      2884.169
# 3                             1.3     2017                     41389.189
# 4                             NaN     2017                     82658.409
# ..                            ...      ...                           ...
# 198                           8.0     2017                     29402.484
# 199                           6.5     2017                     94600.648
# 200                           NaN     2017                     27834.819
# 201                           NaN     2017                     16853.599
# 202                           NaN     2017                     14236.595
#
#      prop. de la pop en ss-alim.
# 0                           29.0
# 1                            5.0
# 2                            3.0
# 3                            3.0
# 4                            NaN
# ..                           ...
# 198                         27.0
# 199                          7.0
# 200                          NaN
# 201                          NaN
# 202                          NaN
#
# [203 rows x 6 columns]

# %%
merge_ss_nut_pop_2017.sort_values("prop. de la pop en ss-alim.", ascending= False).head(10)
# Out:
#                                            Pays  Année_x  \
# 78                                        Haïti     2017
# 157  République populaire démocratique de Corée     2017
# 108                                  Madagascar     2017
# 100                                     Lesotho     2017
# 103                                     Libéria     2017
# 183                                       Tchad     2017
# 161                                      Rwanda     2017
# 121                                  Mozambique     2017
# 186                                 Timor-Leste     2017
# 0                                   Afghanistan     2017
#
#      Individus en millions d'hab.  Année_y  Individus en milliers d'hab.  \
# 78                            5.3     2017                     10982.366
# 157                          12.0     2017                     25429.825
# 108                          10.5     2017                     25570.512
# 100                           0.8     2017                      2091.534
# 103                           1.8     2017                      4702.226
# 183                           5.7     2017                     15016.753
# 161                           4.2     2017                     11980.961
# 121                           9.4     2017                     28649.018
# 186                           0.4     2017                      1243.258
# 0                            10.5     2017                     36296.113
#
#      prop. de la pop en ss-alim.
# 78                          48.0
# 157                         47.0
# 108                         41.0
# 100                         38.0
# 103                         38.0
# 183                         38.0
# 161                         35.0
# 121                         33.0
# 186                         32.0
# 0                           29.0

# %% [markdown]
# Ci-dessus, **un top 10 des populations qui présentent les proportions les plus élevés de sous-nutritions**. Les résultats sont à peines croyables... **Haïti est en première position** avec près de la moitié de sa population soit plus de **2 millions de personnes** en état de sous nutrition...

# %% [markdown]
# # Deuxième question : Quels sont les pays  qui ont bénéficié du plus d’aide depuis 2013 ?

# %% [markdown]
# Pour répondre à cette question nous auront besoin du df **aide_alimentaire**

# %%
aide_alimentaire.head()
# Out:
#   Pays bénéficiaire  Année              Produit  Valeur
# 0       Afghanistan   2013  Autres non-céréales     682
# 1       Afghanistan   2014  Autres non-céréales     335
# 2       Afghanistan   2013         Blé et Farin   39224
# 3       Afghanistan   2014         Blé et Farin   15160
# 4       Afghanistan   2013             Céréales   40504

# %% [markdown]
# Jetons un oeil au **type de données**

# %%
aide_alimentaire.dtypes
# Out:
# Pays bénéficiaire    object
# Année                 int64
# Produit              object
# Valeur                int64
# dtype: object

# %% [markdown]
# Procédons au changement de type de la colonne année

# %%
aide_alimentaire["Année"] = aide_alimentaire["Année"].astype("object")
aide_alimentaire.dtypes
# Out:
# Pays bénéficiaire    object
# Année                object
# Produit              object
# Valeur                int64
# dtype: object

# %%
aide_alimentaire.groupby('Pays bénéficiaire').sum().sort_values("Valeur",ascending=False).head(10)
# Out:
#                                    Valeur
# Pays bénéficiaire
# République arabe syrienne         1858943
# Éthiopie                          1381294
# Yémen                             1206484
# Soudan du Sud                      695248
# Soudan                             669784
# Kenya                              552836
# Bangladesh                         348188
# Somalie                            292678
# République démocratique du Congo   288502
# Niger                              276344

# %% [markdown]
# Grace à la combinaison des méthodes **. sum(), sort_values()et head()** nous pouvons voir **un Top 10 des Pays ayant reçu le plus d'aide depuis 2013.**

# %% [markdown]
#  # Troisième question : Quels sont les pays ayant le plus/le moins de disponibilité/habitant ?

# %% [markdown]
# Voilà une question à laquelle **nous avons déjà répondu**, il s'agissait d'une étape pour la résolution d'un problème plus grand. La réponse se cache dans le df **dispo_alim_par_pays_inner**. Il suffira de faire un **.sort_values() décroissant**.
# Un **.head(10)** nous donnera les 10 premières valeurs tandis qu'un **.tail(10)** nous donnera les 10 dernières.

# %%
dispo_alim_par_pays_inner.sort_values("kcal/jour", ascending= False).head(10)
# Out:
#                       Pays  Disponibilité alimentaire (Kcal/personne/jour)  \
# 36     Chine, continentale                                          3112.0
# 68                    Inde                                          2454.0
# 169  États-Unis d'Amérique                                          3682.0
# 69               Indonésie                                          2776.0
# 23                  Brésil                                          3262.0
# 108                Nigéria                                          2700.0
# 116               Pakistan                                          2438.0
# 54    Fédération de Russie                                          3360.0
# 14              Bangladesh                                          2453.0
# 100                Mexique                                          3068.0
#
#      Année  Individus en milliers d'hab.     kcal/jour
# 36    2017                   1421021.791  4.422220e+12
# 68    2017                   1338676.785  3.285113e+12
# 169   2017                    325084.756  1.196962e+12
# 69    2017                    264650.963  7.346711e+11
# 23    2017                    207833.823  6.779539e+11
# 108   2017                    190873.244  5.153578e+11
# 116   2017                    207906.209  5.068753e+11
# 54    2017                    145530.082  4.889811e+11
# 14    2017                    159685.424  3.917083e+11
# 100   2017                    124777.324  3.828168e+11

# %%
dispo_alim_par_pays_inner.sort_values("kcal/jour", ascending= False).tail(10)
# Out:
#                                 Pays  \
# 137                            Samoa
# 138             Sao Tomé-et-Principe
# 136                     Sainte-Lucie
# 82                          Kiribati
# 135  Saint-Vincent-et-les Grenadines
# 58                           Grenade
# 6                 Antigua-et-Barbuda
# 46                         Dominique
# 18                          Bermudes
# 134             Saint-Kitts-et-Nevis
#
#      Disponibilité alimentaire (Kcal/personne/jour)  Année  \
# 137                                          2956.0   2017
# 138                                          2398.0   2017
# 136                                          2589.0   2017
# 82                                           3042.0   2017
# 135                                          2965.0   2017
# 58                                           2442.0   2017
# 6                                            2416.0   2017
# 46                                           2930.0   2017
# 18                                           2668.0   2017
# 134                                          2491.0   2017
#
#      Individus en milliers d'hab.    kcal/jour
# 137                       195.352  577460512.0
# 138                       207.089  496599422.0
# 136                       180.954  468489906.0
# 82                        114.158  347268636.0
# 135                       109.827  325637055.0
# 58                        110.874  270754308.0
# 6                          95.426  230549216.0
# 46                         71.458  209371940.0
# 18                         63.049  168214732.0
# 134                        52.045  129644095.0

# %% [markdown]
# # Interrogation relative au Taux d’ autosuffisance (TAS)
#
# **Le taux d’autosuffisance alimentaire est un indice permettant de mesurer l’importance de la production alimentaire d’un pays par rapport à sa consommation intérieure. La question de l’autosuffisance alimentaire n’est pas sans importance, vu la possibilité, qu’il ne faut pas exclure, d’une crise ou d’une situation de pénurie.**
#
# Il se calcule de la manière suivante : **[Production/(Production+Importations-Exportations)]*100**

# %%
dispo_alimentaire
# Out:
#                Pays                Produit   Origine  Aliments pour animaux  \
# 0       Afghanistan       Abats Comestible   animale                    NaN
# 1       Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2       Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3       Afghanistan                 Ananas  vegetale                    NaN
# 4       Afghanistan                Bananes  vegetale                    NaN
# ...             ...                    ...       ...                    ...
# 15600  Îles Salomon       Viande de Suides   animale                    NaN
# 15601  Îles Salomon    Viande de Volailles   animale                    NaN
# 15602  Îles Salomon          Viande, Autre   animale                    NaN
# 15603  Îles Salomon                    Vin  vegetale                    NaN
# 15604  Îles Salomon         Épices, Autres  vegetale                    NaN
#
#        Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                      NaN                                             5.0
# 1                      NaN                                             1.0
# 2                      NaN                                             1.0
# 3                      NaN                                             0.0
# 4                      NaN                                             4.0
# ...                    ...                                             ...
# 15600                  NaN                                            45.0
# 15601                  NaN                                            11.0
# 15602                  NaN                                             0.0
# 15603                  NaN                                             0.0
# 15604                  NaN                                             4.0
#
#        Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                                   1.72
# 1                                                   1.29
# 2                                                   0.06
# 3                                                   0.00
# 4                                                   2.70
# ...                                                  ...
# 15600                                               4.70
# 15601                                               3.34
# 15602                                               0.06
# 15603                                               0.07
# 15604                                               0.48
#
#        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                                   0.20
# 1                                                   0.01
# 2                                                   0.01
# 3                                                    NaN
# 4                                                   0.02
# ...                                                  ...
# 15600                                               4.28
# 15601                                               0.69
# 15602                                                NaN
# 15603                                                NaN
# 15604                                               0.21
#
#        Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                                   0.77
# 1                                                   0.02
# 2                                                   0.03
# 3                                                    NaN
# 4                                                   0.05
# ...                                                  ...
# 15600                                               1.41
# 15601                                               1.14
# 15602                                               0.04
# 15603                                                NaN
# 15604                                               0.15
#
#        Disponibilité intérieure  Exportations - Quantité  \
# 0                          53.0                      NaN
# 1                          41.0                      2.0
# 2                           2.0                      NaN
# 3                           0.0                      NaN
# 4                          82.0                      NaN
# ...                         ...                      ...
# 15600                       3.0                      NaN
# 15601                       2.0                      NaN
# 15602                       0.0                      NaN
# 15603                       0.0                      0.0
# 15604                       0.0                      0.0
#
#        Importations - Quantité  Nourriture  Pertes  Production  Semences  \
# 0                          NaN        53.0     NaN        53.0       NaN
# 1                         40.0        39.0     2.0         3.0       NaN
# 2                          2.0         2.0     NaN         NaN       NaN
# 3                          0.0         0.0     NaN         NaN       NaN
# 4                         82.0        82.0     NaN         NaN       NaN
# ...                        ...         ...     ...         ...       ...
# 15600                      0.0         3.0     NaN         2.0       NaN
# 15601                      2.0         2.0     NaN         0.0       NaN
# 15602                      0.0         0.0     NaN         NaN       NaN
# 15603                      0.0         0.0     NaN         NaN       NaN
# 15604                      0.0         0.0     NaN         0.0       NaN
#
#        Traitement  Variation de stock
# 0             NaN                 NaN
# 1             NaN                 NaN
# 2             NaN                 NaN
# 3             NaN                 NaN
# 4             NaN                 NaN
# ...           ...                 ...
# 15600         NaN                 NaN
# 15601         NaN                 NaN
# 15602         NaN                 NaN
# 15603         NaN                 NaN
# 15604         NaN                 NaN
#
# [15605 rows x 18 columns]

# %%
dispo_alim_par_pays = dispo_alimentaire.groupby("Pays").sum()
dispo_alim_par_pays
# Out:
#                        Aliments pour animaux  Autres Utilisations  \
# Pays
# Afghanistan                            768.0                415.0
# Afrique du Sud                        5309.0                876.0
# Albanie                                660.0                174.0
# Algérie                               4352.0               1707.0
# Allemagne                            30209.0               7711.0
# ...                                      ...                  ...
# Émirats arabes unis                   1174.0               2689.0
# Équateur                              1200.0               1909.0
# États-Unis d'Amérique               148432.0             154699.0
# Éthiopie                               685.0               3641.0
# Îles Salomon                             0.0                237.0
#
#                        Disponibilité alimentaire (Kcal/personne/jour)  \
# Pays
# Afghanistan                                                    2087.0
# Afrique du Sud                                                 3020.0
# Albanie                                                        3188.0
# Algérie                                                        3293.0
# Allemagne                                                      3503.0
# ...                                                               ...
# Émirats arabes unis                                            3275.0
# Équateur                                                       2346.0
# États-Unis d'Amérique                                          3682.0
# Éthiopie                                                       2129.0
# Îles Salomon                                                   2383.0
#
#                        Disponibilité alimentaire en quantité (kg/personne/an)  \
# Pays
# Afghanistan                                                       351.41
# Afrique du Sud                                                    564.80
# Albanie                                                          1095.54
# Algérie                                                           809.13
# Allemagne                                                         957.52
# ...                                                                  ...
# Émirats arabes unis                                               700.24
# Équateur                                                          544.91
# États-Unis d'Amérique                                            1002.39
# Éthiopie                                                          354.55
# Îles Salomon                                                      648.91
#
#                        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Pays
# Afghanistan                                                        33.50
# Afrique du Sud                                                     83.58
# Albanie                                                           106.48
# Algérie                                                            76.48
# Allemagne                                                         141.62
# ...                                                                  ...
# Émirats arabes unis                                                87.16
# Équateur                                                           94.64
# États-Unis d'Amérique                                             161.37
# Éthiopie                                                           25.89
# Îles Salomon                                                       46.99
#
#                        Disponibilité de protéines en quantité (g/personne/jour)  \
# Pays
# Afghanistan                                                        58.26
# Afrique du Sud                                                     85.33
# Albanie                                                           111.37
# Algérie                                                            91.92
# Allemagne                                                         101.39
# ...                                                                  ...
# Émirats arabes unis                                               104.51
# Équateur                                                           61.30
# États-Unis d'Amérique                                             109.42
# Éthiopie                                                           60.39
# Îles Salomon                                                       56.31
#
#                        Disponibilité intérieure  Exportations - Quantité  \
# Pays
# Afghanistan                             13515.0                    278.0
# Afrique du Sud                          61256.0                  11674.0
# Albanie                                  4758.0                     94.0
# Algérie                                 42630.0                    655.0
# Allemagne                              162275.0                  57431.0
# ...                                         ...                      ...
# Émirats arabes unis                     11850.0                   4343.0
# Équateur                                18614.0                   8002.0
# États-Unis d'Amérique                  777992.0                 163524.0
# Éthiopie                                44014.0                    941.0
# Îles Salomon                              695.0                    118.0
#
#                        Importations - Quantité  Nourriture  Pertes  \
# Pays
# Afghanistan                             2988.0     10735.0  1135.0
# Afrique du Sud                          7517.0     29812.0  2193.0
# Albanie                                  933.0      3476.0   276.0
# Algérie                                17403.0     31729.0  3753.0
# Allemagne                              65353.0     79238.0  3781.0
# ...                                        ...         ...     ...
# Émirats arabes unis                    15327.0      6548.0   705.0
# Équateur                                1725.0      8574.0   707.0
# États-Unis d'Amérique                  81887.0    320889.0  7162.0
# Éthiopie                                1711.0     33361.0  2256.0
# Îles Salomon                              81.0       362.0     6.0
#
#                        Production  Semences  Traitement  Variation de stock
# Pays
# Afghanistan               11171.0     395.0        63.0              -368.0
# Afrique du Sud            63263.0     253.0     22819.0              2153.0
# Albanie                    3964.0      55.0       113.0               -45.0
# Algérie                   26359.0     449.0       637.0              -479.0
# Allemagne                154547.0    1551.0     39842.0              -192.0
# ...                           ...       ...         ...                 ...
# Émirats arabes unis        1192.0       3.0       804.0              -327.0
# Équateur                  24337.0     138.0      6200.0               557.0
# États-Unis d'Amérique    894668.0   10403.0    141010.0            -35032.0
# Éthiopie                  46102.0     640.0      3443.0             -2857.0
# Îles Salomon                739.0       0.0        90.0               -10.0
#
# [174 rows x 15 columns]

# %%
dispo_alim_par_pays["TAS"]=(dispo_alim_par_pays["Production"]/(dispo_alim_par_pays["Production"]+dispo_alim_par_pays["Importations - Quantité"]- dispo_alim_par_pays["Exportations - Quantité"]))*100

# %%
dispo_alim_par_pays.sort_values("TAS", ascending= False).head(10)
# Out:
#                   Aliments pour animaux  Autres Utilisations  \
# Pays
# Nouvelle-Zélande                 1733.0               1395.0
# Islande                           107.0                 43.0
# Uruguay                          1239.0                125.0
# Bulgarie                         1055.0                535.0
# Australie                        9236.0               3032.0
# Paraguay                         3657.0                969.0
# Costa Rica                        813.0                170.0
# Lituanie                         1933.0                416.0
# Argentine                        7890.0               4194.0
# Hongrie                          4643.0                203.0
#
#                   Disponibilité alimentaire (Kcal/personne/jour)  \
# Pays
# Nouvelle-Zélande                                          3136.0
# Islande                                                   3381.0
# Uruguay                                                   3052.0
# Bulgarie                                                  2828.0
# Australie                                                 3278.0
# Paraguay                                                  2584.0
# Costa Rica                                                2846.0
# Lituanie                                                  3414.0
# Argentine                                                 3226.0
# Hongrie                                                   3034.0
#
#                   Disponibilité alimentaire en quantité (kg/personne/an)  \
# Pays
# Nouvelle-Zélande                                             844.04
# Islande                                                      923.29
# Uruguay                                                      779.63
# Bulgarie                                                     707.76
# Australie                                                    941.76
# Paraguay                                                     610.98
# Costa Rica                                                   681.79
# Lituanie                                                    1050.07
# Argentine                                                    784.96
# Hongrie                                                      720.36
#
#                   Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Pays
# Nouvelle-Zélande                                             115.87
# Islande                                                      151.35
# Uruguay                                                      105.83
# Bulgarie                                                      93.99
# Australie                                                    150.81
# Paraguay                                                      92.59
# Costa Rica                                                    90.42
# Lituanie                                                      94.44
# Argentine                                                    116.46
# Hongrie                                                      137.48
#
#                   Disponibilité de protéines en quantité (g/personne/jour)  \
# Pays
# Nouvelle-Zélande                                              92.39
# Islande                                                      133.06
# Uruguay                                                       92.33
# Bulgarie                                                      83.41
# Australie                                                    106.26
# Paraguay                                                      70.58
# Costa Rica                                                    75.05
# Lituanie                                                     124.36
# Argentine                                                    102.60
# Hongrie                                                       78.75
#
#                   Disponibilité intérieure  Exportations - Quantité  \
# Pays
# Nouvelle-Zélande                    8127.0                  22805.0
# Islande                              474.0                   1440.0
# Uruguay                             4988.0                   8179.0
# Bulgarie                            9458.0                   9466.0
# Australie                          66992.0                  43184.0
# Paraguay                           17016.0                  10059.0
# Costa Rica                         10049.0                   6291.0
# Lituanie                            7467.0                   5963.0
# Argentine                         114369.0                  52333.0
# Hongrie                            16309.0                  10824.0
#
#                   Importations - Quantité  Nourriture  Pertes  Production  \
# Pays
# Nouvelle-Zélande                   2072.0      3799.0   362.0     26896.0
# Islande                             258.0       301.0     0.0      1657.0
# Uruguay                            1213.0      2658.0   531.0     11587.0
# Bulgarie                           2293.0      5111.0  1090.0     15564.0
# Australie                          5879.0     21988.0   520.0    100956.0
# Paraguay                            523.0      4158.0  1823.0     27321.0
# Costa Rica                         2099.0      3320.0  1058.0     14004.0
# Lituanie                           3060.0      3169.0   147.0      9761.0
# Argentine                          1212.0     32531.0  3522.0    176124.0
# Hongrie                            3571.0      7177.0   411.0     25315.0
#
#                   Semences  Traitement  Variation de stock         TAS
# Pays
# Nouvelle-Zélande      87.0       784.0              1972.0  436.410839
# Islande                1.0        21.0                -2.0  348.842105
# Uruguay              183.0       280.0               372.0  250.746592
# Bulgarie             357.0      1312.0              1077.0  185.484448
# Australie           1098.0     31148.0              3339.0  158.608663
# Paraguay             215.0      6202.0              -771.0  153.618218
# Costa Rica            52.0      4834.0               237.0  142.723196
# Lituanie             381.0      1426.0               616.0  142.330125
# Argentine           2416.0     63983.0            -10632.0  140.895819
# Hongrie              527.0      3372.0             -1751.0  140.156129

# %% [markdown]
# La **Nouvelle-Zélande et l'Islande** tiennent le haut du classement ces pays environs 4 fois plus d'aliment qu'ils n'en consomment. Ils sont **hautement autosuffisant** !

# %%
dispo_alim_par_pays.sort_values("TAS", ascending= False).tail(10)
# Out:
#                           Aliments pour animaux  Autres Utilisations  \
# Pays
# Arabie saoudite                         11841.0                159.0
# Trinité-et-Tobago                          88.0                 37.0
# Antigua-et-Barbuda                          0.0                 20.0
# Brunéi Darussalam                           9.0                 15.0
# Koweït                                    522.0                 93.0
# Bermudes                                    1.0                 22.0
# Émirats arabes unis                      1174.0               2689.0
# Chine - RAS de Hong-Kong                  100.0                312.0
# Djibouti                                    0.0                119.0
# Chine - RAS de Macao                        0.0                 10.0
#
#                           Disponibilité alimentaire (Kcal/personne/jour)  \
# Pays
# Arabie saoudite                                                   3255.0
# Trinité-et-Tobago                                                 3049.0
# Antigua-et-Barbuda                                                2416.0
# Brunéi Darussalam                                                 2985.0
# Koweït                                                            3499.0
# Bermudes                                                          2668.0
# Émirats arabes unis                                               3275.0
# Chine - RAS de Hong-Kong                                          3286.0
# Djibouti                                                          2609.0
# Chine - RAS de Macao                                              2915.0
#
#                           Disponibilité alimentaire en quantité (kg/personne/an)  \
# Pays
# Arabie saoudite                                                      622.78
# Trinité-et-Tobago                                                    661.16
# Antigua-et-Barbuda                                                   694.17
# Brunéi Darussalam                                                    640.91
# Koweït                                                               908.82
# Bermudes                                                             840.70
# Émirats arabes unis                                                  700.24
# Chine - RAS de Hong-Kong                                             802.17
# Djibouti                                                             454.14
# Chine - RAS de Macao                                                 655.38
#
#                           Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Pays
# Arabie saoudite                                                      107.83
# Trinité-et-Tobago                                                     92.55
# Antigua-et-Barbuda                                                    89.76
# Brunéi Darussalam                                                     82.46
# Koweït                                                               116.87
# Bermudes                                                             109.93
# Émirats arabes unis                                                   87.16
# Chine - RAS de Hong-Kong                                             139.82
# Djibouti                                                              59.85
# Chine - RAS de Macao                                                 126.18
#
#                           Disponibilité de protéines en quantité (g/personne/jour)  \
# Pays
# Arabie saoudite                                                       91.59
# Trinité-et-Tobago                                                     83.33
# Antigua-et-Barbuda                                                    83.49
# Brunéi Darussalam                                                     93.29
# Koweït                                                               108.15
# Bermudes                                                              90.36
# Émirats arabes unis                                                  104.51
# Chine - RAS de Hong-Kong                                             129.07
# Djibouti                                                              65.62
# Chine - RAS de Macao                                                  94.75
#
#                           Disponibilité intérieure  Exportations - Quantité  \
# Pays
# Arabie saoudite                            31274.0                   4707.0
# Trinité-et-Tobago                           1072.0                     95.0
# Antigua-et-Barbuda                            79.0                      0.0
# Brunéi Darussalam                            294.0                     11.0
# Koweït                                      3824.0                    467.0
# Bermudes                                      59.0                     24.0
# Émirats arabes unis                        11850.0                   4343.0
# Chine - RAS de Hong-Kong                    6424.0                   3604.0
# Djibouti                                     526.0                    113.0
# Chine - RAS de Macao                         383.0                      2.0
#
#                           Importations - Quantité  Nourriture  Pertes  \
# Pays
# Arabie saoudite                           27726.0     17956.0  1040.0
# Trinité-et-Tobago                           898.0       888.0    19.0
# Antigua-et-Barbuda                           63.0        58.0     0.0
# Brunéi Darussalam                           244.0       261.0     4.0
# Koweït                                     3690.0      3061.0   159.0
# Bermudes                                     77.0        51.0     0.0
# Émirats arabes unis                       15327.0      6548.0   705.0
# Chine - RAS de Hong-Kong                   9510.0      5778.0   216.0
# Djibouti                                   1628.0       393.0    10.0
# Chine - RAS de Macao                        367.0       368.0     1.0
#
#                           Production  Semences  Traitement  \
# Pays
# Arabie saoudite               8878.0      97.0       601.0
# Trinité-et-Tobago              275.0       3.0        32.0
# Antigua-et-Barbuda              20.0       0.0         0.0
# Brunéi Darussalam               60.0       1.0         0.0
# Koweït                         636.0       4.0         1.0
# Bermudes                         6.0       0.0         0.0
# Émirats arabes unis           1192.0       3.0       804.0
# Chine - RAS de Hong-Kong       470.0       2.0        11.0
# Djibouti                        76.0       0.0         0.0
# Chine - RAS de Macao            16.0       0.0         3.0
#
#                           Variation de stock        TAS         TDI  \
# Pays
# Arabie saoudite                       -628.0  27.833339   86.923535
# Trinité-et-Tobago                      -10.0  25.510204   83.302412
# Antigua-et-Barbuda                      -7.0  24.096386   75.903614
# Brunéi Darussalam                       -2.0  20.477816   83.276451
# Koweït                                 -29.0  16.480954   95.620627
# Bermudes                                 0.0  10.169492  130.508475
# Émirats arabes unis                   -327.0   9.789750  125.878778
# Chine - RAS de Hong-Kong                44.0   7.371393  149.153074
# Djibouti                             -1064.0   4.776870  102.325581
# Chine - RAS de Macao                     2.0   4.199475   96.325459
#
#                           Proportion exportation
# Pays
# Arabie saoudite                        53.018698
# Trinité-et-Tobago                      34.545455
# Antigua-et-Barbuda                      0.000000
# Brunéi Darussalam                      18.333333
# Koweït                                 73.427673
# Bermudes                              400.000000
# Émirats arabes unis                   364.345638
# Chine - RAS de Hong-Kong              766.808511
# Djibouti                              148.684211
# Chine - RAS de Macao                   12.500000

# %% [markdown]
# La Région administrative spéciale chinoise de **MACAO** arrive bonne dernière du classement avec un **TAS inférieure à 5 %**

# %% [markdown]
# # Taux de dépendance des importation (TDI)

# %% [markdown]
# La signification du TDI va sans dire il se calcul de la façon suivante :**[Importations/(Production+Importations-Exportations)]*100**

# %%
dispo_alim_par_pays["TDI"]=(dispo_alim_par_pays["Importations - Quantité"]/(dispo_alim_par_pays["Production"]+dispo_alim_par_pays["Importations - Quantité"]- dispo_alim_par_pays["Exportations - Quantité"]))*100
dispo_alim_par_pays
# Out:
#                        Aliments pour animaux  Autres Utilisations  \
# Pays
# Afghanistan                            768.0                415.0
# Afrique du Sud                        5309.0                876.0
# Albanie                                660.0                174.0
# Algérie                               4352.0               1707.0
# Allemagne                            30209.0               7711.0
# ...                                      ...                  ...
# Émirats arabes unis                   1174.0               2689.0
# Équateur                              1200.0               1909.0
# États-Unis d'Amérique               148432.0             154699.0
# Éthiopie                               685.0               3641.0
# Îles Salomon                             0.0                237.0
#
#                        Disponibilité alimentaire (Kcal/personne/jour)  \
# Pays
# Afghanistan                                                    2087.0
# Afrique du Sud                                                 3020.0
# Albanie                                                        3188.0
# Algérie                                                        3293.0
# Allemagne                                                      3503.0
# ...                                                               ...
# Émirats arabes unis                                            3275.0
# Équateur                                                       2346.0
# États-Unis d'Amérique                                          3682.0
# Éthiopie                                                       2129.0
# Îles Salomon                                                   2383.0
#
#                        Disponibilité alimentaire en quantité (kg/personne/an)  \
# Pays
# Afghanistan                                                       351.41
# Afrique du Sud                                                    564.80
# Albanie                                                          1095.54
# Algérie                                                           809.13
# Allemagne                                                         957.52
# ...                                                                  ...
# Émirats arabes unis                                               700.24
# Équateur                                                          544.91
# États-Unis d'Amérique                                            1002.39
# Éthiopie                                                          354.55
# Îles Salomon                                                      648.91
#
#                        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Pays
# Afghanistan                                                        33.50
# Afrique du Sud                                                     83.58
# Albanie                                                           106.48
# Algérie                                                            76.48
# Allemagne                                                         141.62
# ...                                                                  ...
# Émirats arabes unis                                                87.16
# Équateur                                                           94.64
# États-Unis d'Amérique                                             161.37
# Éthiopie                                                           25.89
# Îles Salomon                                                       46.99
#
#                        Disponibilité de protéines en quantité (g/personne/jour)  \
# Pays
# Afghanistan                                                        58.26
# Afrique du Sud                                                     85.33
# Albanie                                                           111.37
# Algérie                                                            91.92
# Allemagne                                                         101.39
# ...                                                                  ...
# Émirats arabes unis                                               104.51
# Équateur                                                           61.30
# États-Unis d'Amérique                                             109.42
# Éthiopie                                                           60.39
# Îles Salomon                                                       56.31
#
#                        Disponibilité intérieure  Exportations - Quantité  \
# Pays
# Afghanistan                             13515.0                    278.0
# Afrique du Sud                          61256.0                  11674.0
# Albanie                                  4758.0                     94.0
# Algérie                                 42630.0                    655.0
# Allemagne                              162275.0                  57431.0
# ...                                         ...                      ...
# Émirats arabes unis                     11850.0                   4343.0
# Équateur                                18614.0                   8002.0
# États-Unis d'Amérique                  777992.0                 163524.0
# Éthiopie                                44014.0                    941.0
# Îles Salomon                              695.0                    118.0
#
#                        Importations - Quantité  Nourriture  Pertes  \
# Pays
# Afghanistan                             2988.0     10735.0  1135.0
# Afrique du Sud                          7517.0     29812.0  2193.0
# Albanie                                  933.0      3476.0   276.0
# Algérie                                17403.0     31729.0  3753.0
# Allemagne                              65353.0     79238.0  3781.0
# ...                                        ...         ...     ...
# Émirats arabes unis                    15327.0      6548.0   705.0
# Équateur                                1725.0      8574.0   707.0
# États-Unis d'Amérique                  81887.0    320889.0  7162.0
# Éthiopie                                1711.0     33361.0  2256.0
# Îles Salomon                              81.0       362.0     6.0
#
#                        Production  Semences  Traitement  Variation de stock  \
# Pays
# Afghanistan               11171.0     395.0        63.0              -368.0
# Afrique du Sud            63263.0     253.0     22819.0              2153.0
# Albanie                    3964.0      55.0       113.0               -45.0
# Algérie                   26359.0     449.0       637.0              -479.0
# Allemagne                154547.0    1551.0     39842.0              -192.0
# ...                           ...       ...         ...                 ...
# Émirats arabes unis        1192.0       3.0       804.0              -327.0
# Équateur                  24337.0     138.0      6200.0               557.0
# États-Unis d'Amérique    894668.0   10403.0    141010.0            -35032.0
# Éthiopie                  46102.0     640.0      3443.0             -2857.0
# Îles Salomon                739.0       0.0        90.0               -10.0
#
#                               TAS         TDI
# Pays
# Afghanistan             80.476911   21.525827
# Afrique du Sud         107.033127   12.717829
# Albanie                 82.531751   19.425359
# Algérie                 61.147841   40.371633
# Allemagne               95.123993   40.224904
# ...                           ...         ...
# Émirats arabes unis      9.789750  125.878778
# Équateur               134.756368    9.551495
# États-Unis d'Amérique  110.041069   10.071818
# Éthiopie                98.357228    3.650367
# Îles Salomon           105.270655   11.538462
#
# [174 rows x 17 columns]

# %%
dispo_alim_par_pays.sort_values("TDI", ascending=False).head(10)
# Out:
#                           Aliments pour animaux  Autres Utilisations  \
# Pays
# Chine - RAS de Hong-Kong                  100.0                312.0
# Bermudes                                    1.0                 22.0
# Luxembourg                                147.0                 11.0
# Émirats arabes unis                      1174.0               2689.0
# Pays-Bas                                 8991.0               4299.0
# Belgique                                 5533.0               3226.0
# Djibouti                                    0.0                119.0
# Oman                                      166.0                285.0
# Chine - RAS de Macao                        0.0                 10.0
# Koweït                                    522.0                 93.0
#
#                           Disponibilité alimentaire (Kcal/personne/jour)  \
# Pays
# Chine - RAS de Hong-Kong                                          3286.0
# Bermudes                                                          2668.0
# Luxembourg                                                        3540.0
# Émirats arabes unis                                               3275.0
# Pays-Bas                                                          3222.0
# Belgique                                                          3737.0
# Djibouti                                                          2609.0
# Oman                                                              3140.0
# Chine - RAS de Macao                                              2915.0
# Koweït                                                            3499.0
#
#                           Disponibilité alimentaire en quantité (kg/personne/an)  \
# Pays
# Chine - RAS de Hong-Kong                                             802.17
# Bermudes                                                             840.70
# Luxembourg                                                          1150.66
# Émirats arabes unis                                                  700.24
# Pays-Bas                                                            1069.22
# Belgique                                                            1002.09
# Djibouti                                                             454.14
# Oman                                                                 821.33
# Chine - RAS de Macao                                                 655.38
# Koweït                                                               908.82
#
#                           Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Pays
# Chine - RAS de Hong-Kong                                             139.82
# Bermudes                                                             109.93
# Luxembourg                                                           141.49
# Émirats arabes unis                                                   87.16
# Pays-Bas                                                             125.30
# Belgique                                                             161.95
# Djibouti                                                              59.85
# Oman                                                                  90.30
# Chine - RAS de Macao                                                 126.18
# Koweït                                                               116.87
#
#                           Disponibilité de protéines en quantité (g/personne/jour)  \
# Pays
# Chine - RAS de Hong-Kong                                             129.07
# Bermudes                                                              90.36
# Luxembourg                                                           113.64
# Émirats arabes unis                                                  104.51
# Pays-Bas                                                             111.46
# Belgique                                                              99.37
# Djibouti                                                              65.62
# Oman                                                                  88.21
# Chine - RAS de Macao                                                  94.75
# Koweït                                                               108.15
#
#                           Disponibilité intérieure  Exportations - Quantité  \
# Pays
# Chine - RAS de Hong-Kong                    6424.0                   3604.0
# Bermudes                                      59.0                     24.0
# Luxembourg                                   802.0                    821.0
# Émirats arabes unis                        11850.0                   4343.0
# Pays-Bas                                   42461.0                  52179.0
# Belgique                                   29358.0                  30345.0
# Djibouti                                     526.0                    113.0
# Oman                                        3518.0                   1217.0
# Chine - RAS de Macao                         383.0                      2.0
# Koweït                                      3824.0                    467.0
#
#                           Importations - Quantité  Nourriture  Pertes  \
# Pays
# Chine - RAS de Hong-Kong                   9510.0      5778.0   216.0
# Bermudes                                     77.0        51.0     0.0
# Luxembourg                                 1076.0       607.0    11.0
# Émirats arabes unis                       15327.0      6548.0   705.0
# Pays-Bas                                  52910.0     17924.0   597.0
# Belgique                                  35276.0     11134.0   564.0
# Djibouti                                   1628.0       393.0    10.0
# Oman                                       3464.0      2984.0   113.0
# Chine - RAS de Macao                        367.0       368.0     1.0
# Koweït                                     3690.0      3061.0   159.0
#
#                           Production  Semences  Traitement  \
# Pays
# Chine - RAS de Hong-Kong       470.0       2.0        11.0
# Bermudes                         6.0       0.0         0.0
# Luxembourg                     593.0       9.0        24.0
# Émirats arabes unis           1192.0       3.0       804.0
# Pays-Bas                     41636.0     403.0     10510.0
# Belgique                     24496.0     153.0      8960.0
# Djibouti                        76.0       0.0         0.0
# Oman                          1169.0       0.0         0.0
# Chine - RAS de Macao            16.0       0.0         3.0
# Koweït                         636.0       4.0         1.0
#
#                           Variation de stock         TDI        TAS
# Pays
# Chine - RAS de Hong-Kong                44.0  149.153074   7.371393
# Bermudes                                 0.0  130.508475  10.169492
# Luxembourg                             -41.0  126.886792  69.929245
# Émirats arabes unis                   -327.0  125.878778   9.789750
# Pays-Bas                                91.0  124.884934  98.274601
# Belgique                               -64.0  119.876304  83.243280
# Djibouti                             -1064.0  102.325581   4.776870
# Oman                                   105.0  101.405152  34.221311
# Chine - RAS de Macao                     2.0   96.325459   4.199475
# Koweït                                 -29.0   95.620627  16.480954

# %% [markdown]
# **Hong-Kong** dépend fortement de ses importations tout comme **Luxembourg ou la Belgique par exemple.**

# %%
dispo_alim_par_pays.sort_values("TDI", ascending=False).tail(10)
# Out:
#                                        Aliments pour animaux  \
# Pays
# Pakistan                                              4755.0
# République centrafricaine                                1.0
# Paraguay                                              3657.0
# Cambodge                                               607.0
# Myanmar                                              11663.0
# République démocratique populaire lao                 1018.0
# Malawi                                                4009.0
# Inde                                                 49129.0
# Brésil                                               63740.0
# Argentine                                             7890.0
#
#                                        Autres Utilisations  \
# Pays
# Pakistan                                            3087.0
# République centrafricaine                             27.0
# Paraguay                                             969.0
# Cambodge                                            9428.0
# Myanmar                                             4542.0
# République démocratique populaire lao               2221.0
# Malawi                                              1296.0
# Inde                                               15162.0
# Brésil                                            367300.0
# Argentine                                           4194.0
#
#                                        Disponibilité alimentaire (Kcal/personne/jour)  \
# Pays
# Pakistan                                                                       2438.0
# République centrafricaine                                                      1879.0
# Paraguay                                                                       2584.0
# Cambodge                                                                       2473.0
# Myanmar                                                                        2574.0
# République démocratique populaire lao                                          2455.0
# Malawi                                                                         2364.0
# Inde                                                                           2454.0
# Brésil                                                                         3262.0
# Argentine                                                                      3226.0
#
#                                        Disponibilité alimentaire en quantité (kg/personne/an)  \
# Pays
# Pakistan                                                                          496.85
# République centrafricaine                                                         453.73
# Paraguay                                                                          610.98
# Cambodge                                                                          410.36
# Myanmar                                                                           484.24
# République démocratique populaire lao                                             632.20
# Malawi                                                                            526.02
# Inde                                                                              494.93
# Brésil                                                                            779.79
# Argentine                                                                         784.96
#
#                                        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Pays
# Pakistan                                                                           74.88
# République centrafricaine                                                          59.41
# Paraguay                                                                           92.59
# Cambodge                                                                           35.93
# Myanmar                                                                            69.42
# République démocratique populaire lao                                              38.86
# Malawi                                                                             41.17
# Inde                                                                               52.49
# Brésil                                                                            117.72
# Argentine                                                                         116.46
#
#                                        Disponibilité de protéines en quantité (g/personne/jour)  \
# Pays
# Pakistan                                                                           65.45
# République centrafricaine                                                          46.04
# Paraguay                                                                           70.58
# Cambodge                                                                           65.66
# Myanmar                                                                            82.61
# République démocratique populaire lao                                              68.89
# Malawi                                                                             64.53
# Inde                                                                               59.91
# Brésil                                                                             95.01
# Argentine                                                                         102.60
#
#                                        Disponibilité intérieure  \
# Pays
# Pakistan                                               168631.0
# République centrafricaine                                2582.0
# Paraguay                                                17016.0
# Cambodge                                                18839.0
# Myanmar                                                 59191.0
# République démocratique populaire lao                    8308.0
# Malawi                                                  19877.0
# Inde                                                  1100838.0
# Brésil                                                1033314.0
# Argentine                                              114369.0
#
#                                        Exportations - Quantité  \
# Pays
# Pakistan                                                9256.0
# République centrafricaine                                  0.0
# Paraguay                                               10059.0
# Cambodge                                                 793.0
# Myanmar                                                 2669.0
# République démocratique populaire lao                    307.0
# Malawi                                                   366.0
# Inde                                                   40807.0
# Brésil                                                126552.0
# Argentine                                              52333.0
#
#                                        Importations - Quantité  Nourriture  \
# Pays
# Pakistan                                                5561.0     90495.0
# République centrafricaine                                 76.0      2092.0
# Paraguay                                                 523.0      4158.0
# Cambodge                                                 477.0      6210.0
# Myanmar                                                 1465.0     25793.0
# République démocratique populaire lao                    165.0      4280.0
# Malawi                                                   395.0      8607.0
# Inde                                                   18954.0    619168.0
# Brésil                                                 16817.0    156246.0
# Argentine                                               1212.0     32531.0
#
#                                         Pertes  Production  Semences  \
# Pays
# Pakistan                                5897.0    172886.0    8443.0
# République centrafricaine                122.0      2503.0      63.0
# Paraguay                                1823.0     27321.0     215.0
# Cambodge                                1984.0     18785.0     272.0
# Myanmar                                 2398.0     59939.0    1382.0
# République démocratique populaire lao    435.0      8430.0     148.0
# Malawi                                  2428.0     19931.0     354.0
# Inde                                   55930.0   1126270.0   29432.0
# Brésil                                 75914.0   1143605.0    2884.0
# Argentine                               3522.0    176124.0    2416.0
#
#                                        Traitement  Variation de stock  \
# Pays
# Pakistan                                  56028.0              -557.0
# République centrafricaine                   278.0                 3.0
# Paraguay                                   6202.0              -771.0
# Cambodge                                    345.0               362.0
# Myanmar                                   13418.0               455.0
# République démocratique populaire lao       205.0                17.0
# Malawi                                     3191.0               -82.0
# Inde                                     332123.0             -3573.0
# Brésil                                   367282.0              -556.0
# Argentine                                 63983.0            -10632.0
#
#                                             TDI         TAS
# Pays
# Pakistan                               3.286818  102.183922
# République centrafricaine              2.946879   97.053121
# Paraguay                               2.940680  153.618218
# Cambodge                               2.582706  101.710975
# Myanmar                                2.494254  102.049885
# République démocratique populaire lao  1.990830  101.713320
# Malawi                                 1.978958   99.854709
# Inde                                   1.716200  101.978691
# Brésil                                 1.626607  110.614004
# Argentine                              0.969577  140.895819

# %% [markdown]
# **Le Pakistan** quant à lui fait figure de meilleur élève en ce qui concerne le TDI .

# %% [markdown]
# # Interrogations de Julien

# %% [markdown]
# # Première interrogation : Quels est le lien logique entre l’ensemble des 10 variables exprimées en milliers de tonnes, qui peut s’exprimer avec une équation du type : A1 + A2 + … = disponibilité intérieure = B1 + B2 + … ?

# %% [markdown]
# D'après la FAO, il faut distinguer la consommation intérieure (aussi appelée utilisations) et la disponibilité intérieure (aussi appelée nourriture). A partir de ces informations, on peut en déduire que :
#
# **Production + (importations - exportations) + variation de stocks = Disponibilité intérieure =aliment pour animaux + nourriture + semences + pertes + traitement + autres utilisations**
#
# Nous uliserons ici l'exemple du blé italien pour vérifier l'exactitude de ces égalités

# %%
ble_italie = dispo_alimentaire.loc[(dispo_alimentaire['Pays'] == "Italie") & (dispo_alimentaire['Produit'] == 'Blé')]
ble_italie["Disponibilité intérieure"].sum()
# Out:
# 11050.0

# %%
disponibilité_intérieure_italie=ble_italie["Disponibilité intérieure"].sum()
conso_int_fb = ble_italie['Aliments pour animaux'].sum() + ble_italie['Nourriture'].sum() + ble_italie['Semences'].sum() + ble_italie['Pertes'].sum() + ble_italie['Traitement'].sum() + ble_italie['Autres Utilisations'].sum()
print('Consommation intérieure de blé en Italie : ' + str(conso_int_fb))
# Out:
# Consommation intérieure de blé en Italie : 11050.0

# %%
prod_fb = ble_italie['Production'].sum() + (ble_italie['Importations - Quantité'].sum() - ble_italie['Exportations - Quantité'].sum()) + ble_italie['Variation de stock'].sum()
print('Production + imports/exports + variation de stock de blé en Italie : ' + str(prod_fb))
# Out:
# Production + imports/exports + variation de stock de blé en France : 11050.0

# %% [markdown]
# # Observation concernant l’utilisation des céréales: notamment la répartition entre l’alimentation humaine (colonne Nourriture) et l’alimentation pour animaux.

# %% [markdown]
# Création d'une liste regroupant les céréales

# %%
cereales= ['Blé', 'Céréales, Autres', 'Maïs', 'Millet','Orge', 'Riz (Eq Blanchi)', 'Avoine', 'Sorgho', 'Seigle']

# %% [markdown]
# Création d'un df regroupant les **disponibilité alimentaires des produits céréaliers**

# %%
dispo_cereales= dispo_alimentaire.loc[dispo_alimentaire["Produit"].isin(cereales)]
dispo_cereales
# Out:
#                Pays           Produit   Origine  Aliments pour animaux  \
# 7       Afghanistan               Blé  vegetale                    NaN
# 12      Afghanistan  Céréales, Autres  vegetale                    NaN
# 32      Afghanistan              Maïs  vegetale                  200.0
# 34      Afghanistan            Millet  vegetale                    NaN
# 40      Afghanistan              Orge  vegetale                  360.0
# ...             ...               ...       ...                    ...
# 15545  Îles Salomon  Céréales, Autres  vegetale                    NaN
# 15568  Îles Salomon              Maïs  vegetale                    NaN
# 15575  Îles Salomon              Orge  vegetale                    NaN
# 15591  Îles Salomon  Riz (Eq Blanchi)  vegetale                    0.0
# 15593  Îles Salomon            Sorgho  vegetale                    0.0
#
#        Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 7                      NaN                                          1369.0
# 12                     NaN                                             0.0
# 32                     NaN                                            21.0
# 34                     NaN                                             3.0
# 40                     NaN                                            26.0
# ...                    ...                                             ...
# 15545                  NaN                                             0.0
# 15568                  NaN                                             1.0
# 15575                  NaN                                             0.0
# 15591                 12.0                                           623.0
# 15593                  NaN                                             NaN
#
#        Disponibilité alimentaire en quantité (kg/personne/an)  \
# 7                                                 160.23
# 12                                                  0.00
# 32                                                  2.50
# 34                                                  0.40
# 40                                                  2.92
# ...                                                  ...
# 15545                                               0.00
# 15568                                               0.15
# 15575                                               0.07
# 15591                                              63.76
# 15593                                                NaN
#
#        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 7                                                   4.69
# 12                                                  0.00
# 32                                                  0.30
# 34                                                  0.02
# 40                                                  0.24
# ...                                                  ...
# 15545                                               0.00
# 15568                                               0.01
# 15575                                                NaN
# 15591                                               1.36
# 15593                                                NaN
#
#        Disponibilité de protéines en quantité (g/personne/jour)  \
# 7                                                  36.91
# 12                                                  0.00
# 32                                                  0.56
# 34                                                  0.08
# 40                                                  0.79
# ...                                                  ...
# 15545                                               0.00
# 15568                                               0.03
# 15575                                               0.01
# 15591                                              10.90
# 15593                                                NaN
#
#        Disponibilité intérieure  Exportations - Quantité  \
# 7                        5992.0                      NaN
# 12                          0.0                      NaN
# 32                        313.0                      0.0
# 34                         13.0                      NaN
# 40                        524.0                      NaN
# ...                         ...                      ...
# 15545                       0.0                      NaN
# 15568                       0.0                      NaN
# 15575                       1.0                      NaN
# 15591                      49.0                      0.0
# 15593                       0.0                      NaN
#
#        Importations - Quantité  Nourriture  Pertes  Production  Semences  \
# 7                       1173.0      4895.0   775.0      5169.0     322.0
# 12                         0.0         0.0     NaN         NaN       NaN
# 32                         1.0        76.0    31.0       312.0       5.0
# 34                         NaN        12.0     1.0        13.0       0.0
# 40                        10.0        89.0    52.0       514.0      22.0
# ...                        ...         ...     ...         ...       ...
# 15545                      0.0         0.0     0.0         NaN       NaN
# 15568                      0.0         0.0     NaN         NaN       NaN
# 15575                      1.0         0.0     NaN         NaN       NaN
# 15591                     47.0        36.0     1.0         3.0       0.0
# 15593                      0.0         NaN     NaN         NaN       NaN
#
#        Traitement  Variation de stock
# 7             NaN              -350.0
# 12            NaN                 NaN
# 32            NaN                 NaN
# 34            NaN                 NaN
# 40            NaN                 0.0
# ...           ...                 ...
# 15545         NaN                 NaN
# 15568         NaN                 NaN
# 15575         1.0                 NaN
# 15591         NaN                 0.0
# 15593         NaN                 NaN
#
# [1497 rows x 18 columns]

# %%
dispo_cereales["Disponibilité intérieure"].sum()
# Out:
# 2406999.0

# %%
round(dispo_cereales["Aliments pour animaux"].sum() / dispo_cereales["Disponibilité intérieure"].sum()*100,2)
# Out:
# 36.29

# %%
round(dispo_cereales["Nourriture"].sum() / dispo_cereales["Disponibilité intérieure"].sum()*100,2)
# Out:
# 42.75

# %% [markdown]
# # Observation relative à l'utilisation du manioc par la Thaïlande

# %%
dispo_alimentaire
# Out:
#                Pays                Produit   Origine  Aliments pour animaux  \
# 0       Afghanistan       Abats Comestible   animale                    NaN
# 1       Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2       Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3       Afghanistan                 Ananas  vegetale                    NaN
# 4       Afghanistan                Bananes  vegetale                    NaN
# ...             ...                    ...       ...                    ...
# 15600  Îles Salomon       Viande de Suides   animale                    NaN
# 15601  Îles Salomon    Viande de Volailles   animale                    NaN
# 15602  Îles Salomon          Viande, Autre   animale                    NaN
# 15603  Îles Salomon                    Vin  vegetale                    NaN
# 15604  Îles Salomon         Épices, Autres  vegetale                    NaN
#
#        Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                      NaN                                             5.0
# 1                      NaN                                             1.0
# 2                      NaN                                             1.0
# 3                      NaN                                             0.0
# 4                      NaN                                             4.0
# ...                    ...                                             ...
# 15600                  NaN                                            45.0
# 15601                  NaN                                            11.0
# 15602                  NaN                                             0.0
# 15603                  NaN                                             0.0
# 15604                  NaN                                             4.0
#
#        Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                                   1.72
# 1                                                   1.29
# 2                                                   0.06
# 3                                                   0.00
# 4                                                   2.70
# ...                                                  ...
# 15600                                               4.70
# 15601                                               3.34
# 15602                                               0.06
# 15603                                               0.07
# 15604                                               0.48
#
#        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                                   0.20
# 1                                                   0.01
# 2                                                   0.01
# 3                                                    NaN
# 4                                                   0.02
# ...                                                  ...
# 15600                                               4.28
# 15601                                               0.69
# 15602                                                NaN
# 15603                                                NaN
# 15604                                               0.21
#
#        Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                                   0.77
# 1                                                   0.02
# 2                                                   0.03
# 3                                                    NaN
# 4                                                   0.05
# ...                                                  ...
# 15600                                               1.41
# 15601                                               1.14
# 15602                                               0.04
# 15603                                                NaN
# 15604                                               0.15
#
#        Disponibilité intérieure  Exportations - Quantité  \
# 0                          53.0                      NaN
# 1                          41.0                      2.0
# 2                           2.0                      NaN
# 3                           0.0                      NaN
# 4                          82.0                      NaN
# ...                         ...                      ...
# 15600                       3.0                      NaN
# 15601                       2.0                      NaN
# 15602                       0.0                      NaN
# 15603                       0.0                      0.0
# 15604                       0.0                      0.0
#
#        Importations - Quantité  Nourriture  Pertes  Production  Semences  \
# 0                          NaN        53.0     NaN        53.0       NaN
# 1                         40.0        39.0     2.0         3.0       NaN
# 2                          2.0         2.0     NaN         NaN       NaN
# 3                          0.0         0.0     NaN         NaN       NaN
# 4                         82.0        82.0     NaN         NaN       NaN
# ...                        ...         ...     ...         ...       ...
# 15600                      0.0         3.0     NaN         2.0       NaN
# 15601                      2.0         2.0     NaN         0.0       NaN
# 15602                      0.0         0.0     NaN         NaN       NaN
# 15603                      0.0         0.0     NaN         NaN       NaN
# 15604                      0.0         0.0     NaN         0.0       NaN
#
#        Traitement  Variation de stock
# 0             NaN                 NaN
# 1             NaN                 NaN
# 2             NaN                 NaN
# 3             NaN                 NaN
# 4             NaN                 NaN
# ...           ...                 ...
# 15600         NaN                 NaN
# 15601         NaN                 NaN
# 15602         NaN                 NaN
# 15603         NaN                 NaN
# 15604         NaN                 NaN
#
# [15605 rows x 18 columns]

# %% [markdown]
# Création d'un dataframe "thailande" derivé du df dispo_alimentaire concernant la thailande et le manioc.

# %%
thailande = dispo_alimentaire.loc[(dispo_alimentaire['Pays']=="Thaïlande")&(dispo_alimentaire["Produit"]=="Manioc")]
thailande
# Out:
#             Pays Produit   Origine  Aliments pour animaux  \
# 13809  Thaïlande  Manioc  vegetale                 1800.0
#
#        Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 13809               2081.0                                            40.0
#
#        Disponibilité alimentaire en quantité (kg/personne/an)  \
# 13809                                               13.0
#
#        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 13809                                               0.05
#
#        Disponibilité de protéines en quantité (g/personne/jour)  \
# 13809                                               0.14
#
#        Disponibilité intérieure  Exportations - Quantité  \
# 13809                    6264.0                  25214.0
#
#        Importations - Quantité  Nourriture  Pertes  Production  Semences  \
# 13809                   1250.0       871.0  1511.0     30228.0       NaN
#
#        Traitement  Variation de stock
# 13809         0.0                 0.0

# %%
print("Proportion de manioc exportée par la Thaïlande :", thailande['Exportations - Quantité'].sum(), "milliers de tonnes.")
# Out:
# Proportion de manioc exportée par la Thaïlande : 25214.0 milliers de tonnes.

# %%
pop_thailande = pop_2017.loc[pop_2017['Pays']=="Thaïlande"]
print ( " Population Thailandaise :", pop_thailande["Individus en milliers d'hab."].sum()*1000)
pop_thailande
# Out:
#  Population Thailandaise : 69209810.0
#            Pays  Année  Individus en milliers d'hab.
# 1312  Thaïlande   2017                      69209.81

# %%
ss_nut_thailande = ss_nut_2017.loc[ss_nut_2017["Pays"]=="Thaïlande"]
ss_nut_thailande
# Out:
#            Pays  Année  Individus en millions d'hab.
# 1114  Thaïlande   2017                           6.2

# %%
pct_ss_nut_thailande = round((6.2*1000000) /(69209810.0)*100 ,2)

# %%
print('Pourcentage de thaïlandais sous-alimentés : ' + str(pct_ss_nut_thailande) +'%')
# Out:
# Pourcentage de thaïlandais sous-alimentés : 8.96%

# %% [markdown]
# Julien a tout à fait raison, on peut s'intérroger sur **le choix que fait la Thailande d'exporter autant de Manioc** alors que plus d'**un Thailandais sur 10 est en état de sous nutrition** .

# %% [markdown]
# Mais la question que l'on pourrait se poser est de savoir s'il existe d'autres pays, qui malgrè un taux de sous-nutrition au moins aussi important, exportent une grande proportion de leur production ?
# Pour répondre à cette question c'est du df **dispo_alim_par_pays** dont on aura besoin.

# %%
dispo_alim_par_pays
# Out:
#                        Aliments pour animaux  Autres Utilisations  \
# Pays
# Afghanistan                            768.0                415.0
# Afrique du Sud                        5309.0                876.0
# Albanie                                660.0                174.0
# Algérie                               4352.0               1707.0
# Allemagne                            30209.0               7711.0
# ...                                      ...                  ...
# Émirats arabes unis                   1174.0               2689.0
# Équateur                              1200.0               1909.0
# États-Unis d'Amérique               148432.0             154699.0
# Éthiopie                               685.0               3641.0
# Îles Salomon                             0.0                237.0
#
#                        Disponibilité alimentaire (Kcal/personne/jour)  \
# Pays
# Afghanistan                                                    2087.0
# Afrique du Sud                                                 3020.0
# Albanie                                                        3188.0
# Algérie                                                        3293.0
# Allemagne                                                      3503.0
# ...                                                               ...
# Émirats arabes unis                                            3275.0
# Équateur                                                       2346.0
# États-Unis d'Amérique                                          3682.0
# Éthiopie                                                       2129.0
# Îles Salomon                                                   2383.0
#
#                        Disponibilité alimentaire en quantité (kg/personne/an)  \
# Pays
# Afghanistan                                                       351.41
# Afrique du Sud                                                    564.80
# Albanie                                                          1095.54
# Algérie                                                           809.13
# Allemagne                                                         957.52
# ...                                                                  ...
# Émirats arabes unis                                               700.24
# Équateur                                                          544.91
# États-Unis d'Amérique                                            1002.39
# Éthiopie                                                          354.55
# Îles Salomon                                                      648.91
#
#                        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Pays
# Afghanistan                                                        33.50
# Afrique du Sud                                                     83.58
# Albanie                                                           106.48
# Algérie                                                            76.48
# Allemagne                                                         141.62
# ...                                                                  ...
# Émirats arabes unis                                                87.16
# Équateur                                                           94.64
# États-Unis d'Amérique                                             161.37
# Éthiopie                                                           25.89
# Îles Salomon                                                       46.99
#
#                        Disponibilité de protéines en quantité (g/personne/jour)  \
# Pays
# Afghanistan                                                        58.26
# Afrique du Sud                                                     85.33
# Albanie                                                           111.37
# Algérie                                                            91.92
# Allemagne                                                         101.39
# ...                                                                  ...
# Émirats arabes unis                                               104.51
# Équateur                                                           61.30
# États-Unis d'Amérique                                             109.42
# Éthiopie                                                           60.39
# Îles Salomon                                                       56.31
#
#                        Disponibilité intérieure  Exportations - Quantité  \
# Pays
# Afghanistan                             13515.0                    278.0
# Afrique du Sud                          61256.0                  11674.0
# Albanie                                  4758.0                     94.0
# Algérie                                 42630.0                    655.0
# Allemagne                              162275.0                  57431.0
# ...                                         ...                      ...
# Émirats arabes unis                     11850.0                   4343.0
# Équateur                                18614.0                   8002.0
# États-Unis d'Amérique                  777992.0                 163524.0
# Éthiopie                                44014.0                    941.0
# Îles Salomon                              695.0                    118.0
#
#                        Importations - Quantité  Nourriture  Pertes  \
# Pays
# Afghanistan                             2988.0     10735.0  1135.0
# Afrique du Sud                          7517.0     29812.0  2193.0
# Albanie                                  933.0      3476.0   276.0
# Algérie                                17403.0     31729.0  3753.0
# Allemagne                              65353.0     79238.0  3781.0
# ...                                        ...         ...     ...
# Émirats arabes unis                    15327.0      6548.0   705.0
# Équateur                                1725.0      8574.0   707.0
# États-Unis d'Amérique                  81887.0    320889.0  7162.0
# Éthiopie                                1711.0     33361.0  2256.0
# Îles Salomon                              81.0       362.0     6.0
#
#                        Production  Semences  Traitement  Variation de stock  \
# Pays
# Afghanistan               11171.0     395.0        63.0              -368.0
# Afrique du Sud            63263.0     253.0     22819.0              2153.0
# Albanie                    3964.0      55.0       113.0               -45.0
# Algérie                   26359.0     449.0       637.0              -479.0
# Allemagne                154547.0    1551.0     39842.0              -192.0
# ...                           ...       ...         ...                 ...
# Émirats arabes unis        1192.0       3.0       804.0              -327.0
# Équateur                  24337.0     138.0      6200.0               557.0
# États-Unis d'Amérique    894668.0   10403.0    141010.0            -35032.0
# Éthiopie                  46102.0     640.0      3443.0             -2857.0
# Îles Salomon                739.0       0.0        90.0               -10.0
#
#                               TAS         TDI
# Pays
# Afghanistan             80.476911   21.525827
# Afrique du Sud         107.033127   12.717829
# Albanie                 82.531751   19.425359
# Algérie                 61.147841   40.371633
# Allemagne               95.123993   40.224904
# ...                           ...         ...
# Émirats arabes unis      9.789750  125.878778
# Équateur               134.756368    9.551495
# États-Unis d'Amérique  110.041069   10.071818
# Éthiopie                98.357228    3.650367
# Îles Salomon           105.270655   11.538462
#
# [174 rows x 17 columns]

# %% [markdown]
# On créer une colonne **"Proportion exportation"** resultat du rapport **des exportations sur la production.**

# %%
dispo_alim_par_pays ["Proportion exportation"] = (dispo_alim_par_pays["Exportations - Quantité"]/dispo_alim_par_pays["Production"])*100

# %%
dispo_alim_par_pays.sort_values("Proportion exportation", ascending=False).head(10)
# Out:
#                           Aliments pour animaux  Autres Utilisations  \
# Pays
# Chine - RAS de Hong-Kong                  100.0                312.0
# Bermudes                                    1.0                 22.0
# Émirats arabes unis                      1174.0               2689.0
# Djibouti                                    0.0                119.0
# Luxembourg                                147.0                 11.0
# Pays-Bas                                 8991.0               4299.0
# Belgique                                 5533.0               3226.0
# Oman                                      166.0                285.0
# Islande                                   107.0                 43.0
# Nouvelle-Zélande                         1733.0               1395.0
#
#                           Disponibilité alimentaire (Kcal/personne/jour)  \
# Pays
# Chine - RAS de Hong-Kong                                          3286.0
# Bermudes                                                          2668.0
# Émirats arabes unis                                               3275.0
# Djibouti                                                          2609.0
# Luxembourg                                                        3540.0
# Pays-Bas                                                          3222.0
# Belgique                                                          3737.0
# Oman                                                              3140.0
# Islande                                                           3381.0
# Nouvelle-Zélande                                                  3136.0
#
#                           Disponibilité alimentaire en quantité (kg/personne/an)  \
# Pays
# Chine - RAS de Hong-Kong                                             802.17
# Bermudes                                                             840.70
# Émirats arabes unis                                                  700.24
# Djibouti                                                             454.14
# Luxembourg                                                          1150.66
# Pays-Bas                                                            1069.22
# Belgique                                                            1002.09
# Oman                                                                 821.33
# Islande                                                              923.29
# Nouvelle-Zélande                                                     844.04
#
#                           Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Pays
# Chine - RAS de Hong-Kong                                             139.82
# Bermudes                                                             109.93
# Émirats arabes unis                                                   87.16
# Djibouti                                                              59.85
# Luxembourg                                                           141.49
# Pays-Bas                                                             125.30
# Belgique                                                             161.95
# Oman                                                                  90.30
# Islande                                                              151.35
# Nouvelle-Zélande                                                     115.87
#
#                           Disponibilité de protéines en quantité (g/personne/jour)  \
# Pays
# Chine - RAS de Hong-Kong                                             129.07
# Bermudes                                                              90.36
# Émirats arabes unis                                                  104.51
# Djibouti                                                              65.62
# Luxembourg                                                           113.64
# Pays-Bas                                                             111.46
# Belgique                                                              99.37
# Oman                                                                  88.21
# Islande                                                              133.06
# Nouvelle-Zélande                                                      92.39
#
#                           Disponibilité intérieure  Exportations - Quantité  \
# Pays
# Chine - RAS de Hong-Kong                    6424.0                   3604.0
# Bermudes                                      59.0                     24.0
# Émirats arabes unis                        11850.0                   4343.0
# Djibouti                                     526.0                    113.0
# Luxembourg                                   802.0                    821.0
# Pays-Bas                                   42461.0                  52179.0
# Belgique                                   29358.0                  30345.0
# Oman                                        3518.0                   1217.0
# Islande                                      474.0                   1440.0
# Nouvelle-Zélande                            8127.0                  22805.0
#
#                           Importations - Quantité  Nourriture  Pertes  \
# Pays
# Chine - RAS de Hong-Kong                   9510.0      5778.0   216.0
# Bermudes                                     77.0        51.0     0.0
# Émirats arabes unis                       15327.0      6548.0   705.0
# Djibouti                                   1628.0       393.0    10.0
# Luxembourg                                 1076.0       607.0    11.0
# Pays-Bas                                  52910.0     17924.0   597.0
# Belgique                                  35276.0     11134.0   564.0
# Oman                                       3464.0      2984.0   113.0
# Islande                                     258.0       301.0     0.0
# Nouvelle-Zélande                           2072.0      3799.0   362.0
#
#                           Production  Semences  Traitement  \
# Pays
# Chine - RAS de Hong-Kong       470.0       2.0        11.0
# Bermudes                         6.0       0.0         0.0
# Émirats arabes unis           1192.0       3.0       804.0
# Djibouti                        76.0       0.0         0.0
# Luxembourg                     593.0       9.0        24.0
# Pays-Bas                     41636.0     403.0     10510.0
# Belgique                     24496.0     153.0      8960.0
# Oman                          1169.0       0.0         0.0
# Islande                       1657.0       1.0        21.0
# Nouvelle-Zélande             26896.0      87.0       784.0
#
#                           Variation de stock         TAS         TDI  \
# Pays
# Chine - RAS de Hong-Kong                44.0    7.371393  149.153074
# Bermudes                                 0.0   10.169492  130.508475
# Émirats arabes unis                   -327.0    9.789750  125.878778
# Djibouti                             -1064.0    4.776870  102.325581
# Luxembourg                             -41.0   69.929245  126.886792
# Pays-Bas                                91.0   98.274601  124.884934
# Belgique                               -64.0   83.243280  119.876304
# Oman                                   105.0   34.221311  101.405152
# Islande                                 -2.0  348.842105   54.315789
# Nouvelle-Zélande                      1972.0  436.410839   33.619990
#
#                           Proportion exportation
# Pays
# Chine - RAS de Hong-Kong              766.808511
# Bermudes                              400.000000
# Émirats arabes unis                   364.345638
# Djibouti                              148.684211
# Luxembourg                            138.448567
# Pays-Bas                              125.321837
# Belgique                              123.877368
# Oman                                  104.106074
# Islande                                86.904043
# Nouvelle-Zélande                       84.789560

# %% [markdown]
# On peut se rendre compte que la **Chine exporte plus de 7 fois ce qu'elle produit** ! **Ce rapport est de 4 fois pour les Bermudes**

# %% [markdown]
# Utilisons le df **merge_ss_nut_pop_2017**

# %%
merge_ss_nut_pop_2017
# Out:
#                                        Pays  Année_x  \
# 0                               Afghanistan     2017
# 1                            Afrique du Sud     2017
# 2                                   Albanie     2017
# 3                                   Algérie     2017
# 4                                 Allemagne     2017
# ..                                      ...      ...
# 198  Venezuela (République bolivarienne du)     2017
# 199                                Viet Nam     2017
# 200                                   Yémen     2017
# 201                                  Zambie     2017
# 202                                Zimbabwe     2017
#
#      Individus en millions d'hab.  Année_y  Individus en milliers d'hab.  \
# 0                            10.5     2017                     36296.113
# 1                             3.1     2017                     57009.756
# 2                             0.1     2017                      2884.169
# 3                             1.3     2017                     41389.189
# 4                             NaN     2017                     82658.409
# ..                            ...      ...                           ...
# 198                           8.0     2017                     29402.484
# 199                           6.5     2017                     94600.648
# 200                           NaN     2017                     27834.819
# 201                           NaN     2017                     16853.599
# 202                           NaN     2017                     14236.595
#
#      prop. de la pop en ss-alim.
# 0                           29.0
# 1                            5.0
# 2                            3.0
# 3                            3.0
# 4                            NaN
# ..                           ...
# 198                         27.0
# 199                          7.0
# 200                          NaN
# 201                          NaN
# 202                          NaN
#
# [203 rows x 6 columns]

# %% [markdown]
# merge avec le df **dispo alimentaire**

# %%
merge_ss_nut_pop_2017_dispo_alim= pd.merge(merge_ss_nut_pop_2017,dispo_alim_par_pays, on='Pays', how="inner" )
merge_ss_nut_pop_2017_dispo_alim= merge_ss_nut_pop_2017_dispo_alim [["Pays","prop. de la pop en ss-alim.","Proportion exportation"]]
merge_ss_nut_pop_2017_dispo_alim
# Out:
#                                        Pays  prop. de la pop en ss-alim.  \
# 0                               Afghanistan                         29.0
# 1                            Afrique du Sud                          5.0
# 2                                   Albanie                          3.0
# 3                                   Algérie                          3.0
# 4                                 Allemagne                          NaN
# ..                                      ...                          ...
# 167  Venezuela (République bolivarienne du)                         27.0
# 168                                Viet Nam                          7.0
# 169                                   Yémen                          NaN
# 170                                  Zambie                          NaN
# 171                                Zimbabwe                          NaN
#
#      Proportion exportation
# 0                  2.488587
# 1                 18.453124
# 2                  2.371342
# 3                  2.484920
# 4                 37.160864
# ..                      ...
# 167                0.259762
# 168               20.907873
# 169               17.430303
# 170                6.412692
# 171                3.512762
#
# [172 rows x 3 columns]

# %%
merge_ss_nut_pop_2017_dispo_alim.loc[merge_ss_nut_pop_2017_dispo_alim['Pays']=="Thaïlande"]
# Out:
#           Pays  prop. de la pop en ss-alim.  Proportion exportation
# 157  Thaïlande                          9.0               24.994548

# %% [markdown]
# La thailande **a 9% de sa population en sous-nutrition** et exporte près **d'un quart de sa production**. Cherchons les pays qui dispose d'**au moins 5% de leur population en état de sous-nutrition** et qui exporte **plus d'un cinquième de leur production**

# %%
merge_ss_nut_pop_2017_dispo_alim.loc[(merge_ss_nut_pop_2017_dispo_alim["prop. de la pop en ss-alim."]>5)&(merge_ss_nut_pop_2017_dispo_alim["Proportion exportation"]>20)]
# Out:
#           Pays  prop. de la pop en ss-alim.  Proportion exportation
# 50    Équateur                          9.0               32.879977
# 84    Jordanie                          8.0               42.936198
# 92       Liban                          6.0               25.686940
# 111    Namibie                         12.0               51.226158
# 119       Oman                          9.0              104.106074
# 124   Paraguay                          9.0               36.817832
# 148  Slovaquie                          6.0               52.293697
# 157  Thaïlande                          9.0               24.994548
# 168   Viet Nam                          7.0               20.907873

# %% [markdown]
# L'exemple **d'Oman est incroyable** ! On a un pays où **une personne sur 10 souffre de sous-nutrition** qui exporte plus de **100% de l'alimentation qu'il produit** !

# %% [markdown]
# # CONCLUSION :
#
# Ce dont on se rend compte, pour conclure ce projet est que, les richesse alimentaire ne manque pas, que ce soit au niveau mondiale, comme à l'échelle des pays en eux même, mis à part quelques exceptions.
# La sous-nutrition nous apparaît plus comme le résultat d'une mauvaise répartition des denrées alimentaires
